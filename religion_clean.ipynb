# %% [markdown]
# <a href="https://colab.research.google.com/github/kcalizadeh/phil_nlp/blob/main/data_load_clean.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Project Introduction

# %% [markdown]
# A book of philosophy represents an effort to systematically organize one's thought about the world. Using the data from the history of philosophy to classify texts thus enable us to, by proxy, classify how people think about the world. Where some projects focus on sentiment analysis, here we focus on conceptual, or ideological analysis.
#
# This project uses 51 texts spanning 10 schools of philosophical thought. Based on these, we develop classification models, word vectors, and general EDA. This can then be used to understand user's worldviews by comparing them to historical schools of thought. And once we understand a person's worldview, there is no limit to what we can do with that information - from advertising to political campaigning through to self-exploration and therapy.
#
# This notebook contains the first steps of that project, where we load the 51 texts in the corpus, clean them, and then produce and export a dataframe for use in modeling.

# %% [markdown]
# ### Imports and Mounting Drive

# %%
# this cell mounts drive, sets the correct directory, then imports all functions
# and relevant libraries via the functions.py file
from google.colab import drive
import sys

# install relevent libraries not included with colab
# !pip install lime
# !pip install symspellpy
# !pip install gensim
drive.mount('/gdrive',force_remount=True)

drive_path = '/gdrive/MyDrive/Colab Notebooks'

sys.path.append(drive_path)
# Out:
# Requirement already satisfied: lime in /usr/local/lib/python3.11/dist-packages (0.2.0.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from lime) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from lime) (1.26.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from lime) (1.13.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from lime) (4.67.1)
# Requirement already satisfied: scikit-learn>=0.18 in /usr/local/lib/python3.11/dist-packages (from lime) (1.6.1)
# Requirement already satisfied: scikit-image>=0.12 in /usr/local/lib/python3.11/dist-packages (from lime) (0.25.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (3.5)
# Requirement already satisfied: pillow>=10.1 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (11.2.1)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2.37.0)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (2025.6.11)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image>=0.12->lime) (0.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.18->lime) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (4.58.5)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->lime) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->lime) (1.17.0)
# Requirement already satisfied: symspellpy in /usr/local/lib/python3.11/dist-packages (6.9.0)
# Requirement already satisfied: editdistpy>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from symspellpy) (0.1.6)
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.3.0.post1)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)
# Mounted at /gdrive

# %%
from functions import *
# %load_ext autoreload
# %autoreload 2
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
import spacy.cli
spacy.cli.download("en_core_web_lg")
import en_core_web_lg
nlp = en_core_web_lg.load()
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %% [markdown]
# ### Load the Texts

# %%
import re
import os
from pathlib import Path


def remove_page_references(text):
    """Remove page references like [p. 84]"""
    text = re.sub(r'\[p\.\s*\d*\]', '', text)
    return text

# %% [markdown]
# With the functions loaded, we bring in the various texts. For access to them via Google Drive, use this [link](https://drive.google.com/drive/folders/1OdTQzRboTOozJqX1INJoYljuA4ctttx8?usp=sharing).

# %%
def clean_tanakh(text):
    """Clean Tanakh"""

    # Remove all numbers
    text = re.sub(r'\d+', '', text)

    # Remove footnotes (single letters)
    text = re.sub(r'\b[a-c]\b', '', text)

    # Remove book markers
    text = re.sub(r'BOOK\s+[IVX]+', '', text, flags=re.IGNORECASE)


    return text


def clean_book_certitude(text):
    """Clean Book of Certitude"""
    # Remove Quran references
    text = re.sub(r'\[Qurían\s+\d+:\d+\.\]', '', text)
    return text


def clean_nature_gods(text):
    """Clean Nature Gods"""
    # Remove Roman numeral markers
    text = re.sub(r'"\s*[IVX]+\s*"\.', '', text)
    return text

def clean_kaivalya_upanishad(text):
    """Clean Kaivalya Upanishad"""
    # Remove numbered sections
    text = re.sub(r'^\d+\.\s*', '', text, flags=re.MULTILINE)
    return text

def clean_kybalion(text):
    """Clean Kybalion"""
    # Remove Kybalion attribution
    text = re.sub(r'--The Kybalion\.', '', text)

    # Convert -- to comma
    text = text.replace('--', ',')

    # Don't convert to capitals (keep original case)
    return text


def clean_secret_teachings_jesus(text):
    """Clean Secret Teachings of the Society of Jesus"""
    # Remove bank information
    text = re.sub(r'BANK of WISDOM.*?40201', '', text, flags=re.DOTALL | re.IGNORECASE)

    # Remove numbered sections
    text = re.sub(r'^\d+\.\s*', '', text, flags=re.MULTILINE)


    return text

# %%
def clean_epistle_son_wolf(text):
    """Clean Epistle to the Son of the Wolf"""
    # Remove questions and exclamations patterns
    text = re.sub(r'[?!]+\s*', ' ', text)
    return text

def clean_bhagavad_gita(text):
    """Clean Bhagavad Gita"""
    # Remove section and chapter markers
    text = re.sub(r'Section\s+"?\d+"?', '', text, flags=re.IGNORECASE)
    text = re.sub(r'Chapter\s+"?\d+"?', '', text, flags=re.IGNORECASE)
    text = re.sub(r'~\s*Chapter\s+"?\d+"?\s*~', '', text, flags=re.IGNORECASE)
    text = re.sub(r'End of Chapter\s+\d+', '', text, flags=re.IGNORECASE)
    text = re.sub(r'Svetasvatara|Prasna-Upanishad', '', text, flags=re.IGNORECASE)

    # Remove quotes section
    text = re.sub(r'And here they quote:', '', text, flags=re.IGNORECASE)

    # Convert &c. to etc.
    text = text.replace('&c.', 'etc.')

    # Remove verse references like 6-2:13, 2:13
    text = re.sub(r'\d+-?\d*:\d+', '', text)

    # Remove ordinal numbers and religious terms
    text = re.sub(r'\b(First|Second|Third|Fourth|Fifth|Sixth|Seventh|Eighth|Ninth|Tenth)\b', '', text, flags=re.IGNORECASE)
    text = re.sub(r'\b(Brahmana|Adhyaya|Anuvaka|Valli|Prapathaka|Question|Khanda)\b', '', text, flags=re.IGNORECASE)

    # Remove dialogue patterns
    text = re.sub(r'…\s*asked him', '', text, flags=re.IGNORECASE)
    text = re.sub(r'He replied:', '', text, flags=re.IGNORECASE)

    # Remove names (sequences of capitalized words)
    text = re.sub(r'\b[A-Z][a-z]*\s+from\s+[A-Z][a-z]*\b', '', text)

    return text

def clean_augustine_city_god(text):
    """Clean Augustine City of God and Christian Doctrine"""
    # Remove chapter markers
    text = re.sub(r'Chapter\s+\d+\.—', '', text, flags=re.IGNORECASE)

    # Remove content between underscores (section separators)
    text = re.sub(r'_{10,}.*?_{10,}', '', text, flags=re.DOTALL)

    return text

def clean_dhammapada(text):
    """Clean Dhammapada"""
    # Remove numbered verses
    text = re.sub(r'^\d+\.\s*', '', text, flags=re.MULTILINE)
    text = text.replace('II', '')
    return text

def clean_siri_guru_granth_sahib(text):
    """Clean Siri Guru Granth Sahib"""
    # Remove verse markers
    text = re.sub(r'\|\|"\d+"\|\|', '', text)
    text = re.sub(r'\|Pause\|\|', '', text)
    return text

def clean_tao_te_ching(text):
    """Clean Tao Te Ching"""
    # Remove part markers
    text = re.sub(r'PART\s+[IVX]+\.', '', text, flags=re.IGNORECASE)
    return text

def clean_analects(text):
    """Clean Analects"""
    # Remove chapter markers with Roman numerals
    text = re.sub(r'CHAP\.\s+[IVX]+\.', '', text, flags=re.IGNORECASE)
    return text

# %%
def clean_way_of_virtue_buddha_path_light(text):
    """Clean Way of Virtue (wov), The Life of Buddha, The Path of Light (tpol)"""
    # Remove page references
    text = remove_page_references(text)

    # Ignore capitals (don't remove capital lines)
    return text



def clean_kitab_aqdas(text):
    """Clean Kitab I Aqdas - clean all"""
    # Comprehensive cleaning
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'[()]', '', text) # Remove parentheses
    text = remove_page_references(text)  # Remove page refs
    return text

def clean_vedic_hymns(text):
    """Clean Vedic Hymns - clean all"""
    # Comprehensive cleaning
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = remove_page_references(text)  # Remove page refs
    text = re.sub(r'\[.*?\]', '', text)  # Remove bracket references
    return text

def clean_vedanta_sutras(text):
    """Clean Vedanta Sutras - clean all"""
    # Comprehensive cleaning
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = remove_page_references(text)  # Remove page refs
    text = re.sub(r'\[.*?\]', '', text)  # Remove bracket references
    return text

def clean_gathas_zoroastrianism(text):
    """Clean Gathas Zoroastrianism"""
    # Remove verse markers with single quotes around numbers
    text = re.sub(r"Verse\s+['\"]?\d+['\"]?\s*:", '', text, flags=re.IGNORECASE)

    # Remove yasna markers with single quotes around numbers
    text = re.sub(r"Yasna\s+['\"]?\d+['\"]?\s*:", '', text, flags=re.IGNORECASE)

    # Remove standalone verse and yasna references
    text = re.sub(r"Verse\s+['\"]?\d+['\"]?", '', text, flags=re.IGNORECASE)
    text = re.sub(r"Yasna\s+['\"]?\d+['\"]?", '', text, flags=re.IGNORECASE)

    # Remove any remaining numbered sections
    text = re.sub(r'^\d+\.\s*', '', text, flags=re.MULTILINE)

    return text

# %%
folder_path = drive_path + '/religion/'
advaita_vedanta = get_text(folder_path + 'Advaita_Vedanta.txt')
analects = get_text(folder_path + 'Analects.txt')
bhagavad_gita = get_text(folder_path + 'Bhagavad Gita.txt')
collected_fruits = get_text(folder_path + 'Collected Fruits of Occult Teaching by A.P.Sinnett (1920).txt')
kaivalya_upanishad = get_text(folder_path + 'Kaivalya_Upanishad.txt')
higher_worlds = get_text(folder_path + 'Knowledge of the Higher Worlds - by Rudolf Steiner.txt')
kybalion = get_text(folder_path + 'Kybalion.txt')
popol_vuh = get_text(folder_path + 'Popol Vuh.txt')
secret_teachings = get_text(folder_path + 'Secret Teachings of the Society of Jesus.txt')
guru_granth_sahib = get_text(folder_path + 'Siri Guru Granth Sahib.txt')
tanakh = get_text(folder_path + 'Tanakh.txt')
tao_te_ching = get_text(folder_path + 'Tao Te Ching.txt')
kitab_aqdas = get_text(folder_path + 'The Kitab I Aqdas.txt')
life_of_buddha = get_text(folder_path + 'The Life of Buddha.txt')
city_of_god = get_text(folder_path + 'augustine city of god and christian doctrine.txt')
dhammapada = get_text(folder_path + 'dhammapada.txt')
epistle_son_wolf = get_text(folder_path + 'epistle to the son of the wolf.txt')
gathas = get_text(folder_path + 'gathas zoroastrianism.txt')
book_of_certitude = get_text(folder_path + 'kitab i ilqan book of certitude.txt')
nature_gods = get_text(folder_path + 'nature-gods.txt')
tpol = get_text(folder_path + 'tpol.txt')
vedic_hymns = get_text(folder_path + 'vedic_hymns_readable.txt')
vedanta_sutras = get_text(folder_path + 'vendanta sutras patanjali.txt')
wov = get_text(folder_path + 'wov.txt')
yoga_sutras = get_text(folder_path + 'yoga sutras patanjali.txt')

# Apply specific cleaning functions to each text
analects = clean_analects(analects)
bhagavad_gita = clean_bhagavad_gita(bhagavad_gita)
city_of_god = clean_augustine_city_god(city_of_god)
dhammapada = clean_dhammapada(dhammapada)
epistle_son_wolf = clean_epistle_son_wolf(epistle_son_wolf)
gathas = clean_gathas_zoroastrianism(gathas)
book_of_certitude = clean_book_certitude(book_of_certitude)
kaivalya_upanishad = clean_kaivalya_upanishad(kaivalya_upanishad)
kitab_aqdas = clean_kitab_aqdas(kitab_aqdas)
kybalion = clean_kybalion(kybalion)
life_of_buddha = clean_way_of_virtue_buddha_path_light(life_of_buddha)
nature_gods = clean_nature_gods(nature_gods)
secret_teachings = clean_secret_teachings_jesus(secret_teachings)
guru_granth_sahib = clean_siri_guru_granth_sahib(guru_granth_sahib)
tanakh = clean_tanakh(tanakh)
tao_te_ching = clean_tao_te_ching(tao_te_ching)
tpol = clean_way_of_virtue_buddha_path_light(tpol)
vedanta_sutras = clean_vedanta_sutras(vedanta_sutras)
vedic_hymns = clean_vedic_hymns(vedic_hymns)
wov = clean_way_of_virtue_buddha_path_light(wov)

hindu_texts = [
    advaita_vedanta, bhagavad_gita, kaivalya_upanishad,
    vedanta_sutras, yoga_sutras, vedic_hymns
]

buddhist_texts = [
    life_of_buddha, dhammapada, tpol
]

christian_texts = [
    city_of_god, secret_teachings
]

islamic_texts = [

]

bahai_texts = [
    book_of_certitude, kitab_aqdas, epistle_son_wolf
]

jewish_texts = [
    tanakh
]

sikh_texts = [
    guru_granth_sahib
]

zoroastrian_texts = [
    gathas
]

confucian_texts = [
    analects
]

taoist_texts = [
    tao_te_ching
]

indigenous_texts = [
    popol_vuh
]

occult_esoteric_texts = [
    collected_fruits, higher_worlds, kybalion, nature_gods, wov
]

text_dict_list = {
    'hinduism': hindu_texts,
    'buddhism': buddhist_texts,
    'christianity': christian_texts,
    'islam': islamic_texts,
    'bahai': bahai_texts,
    'judaism': jewish_texts,
    'sikhism': sikh_texts,
    'zoroastrianism': zoroastrian_texts,
    'confucianism': confucian_texts,
    'taoism': taoist_texts,
    'indigenous': indigenous_texts,
    'occult_esoteric': occult_esoteric_texts
}

# %% [markdown]
# Now we cut out front and end-matter. This needs to be done ad hoc, since there is no consistent marker for it.

# %% [markdown]
# Having isolated the relevant portions of each document, we can now unify all the texts in each school.

# %%
all_texts = sum(text_dict_list.values(), [])
all_texts_string = ' . '.join(all_texts)

text_dict = {}
for school in text_dict_list.keys():
    text_dict[school] = ' . '.join(text_dict_list[school])

# %% [markdown]
# ### Preliminary EDA
#
# For a bit of preliminary EDA, we can make word clouds for each school. Here we prepare the text for this with some very basic cleaning to remove encoding artifacts and the like. Then we build the word clouds and present them.

# %%
# some basic initial cleaning
all_texts_string = all_texts_string.replace('signi cance', 'significance').replace('obj ects', 'objects').replace('de nite', 'denote').replace('j ust', 'just')

for school in text_dict.keys():
    text_dict[school] = re.sub(r'[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\xff\xad\x0c6§\[\]\\\£\Â\n\r]', '', text_dict[school])
    text_dict[school] = re.sub(r'[0123456789]', ' ', text_dict[school])
    text_dict[school] = text_dict[school].replace('signi cance', 'significance').replace('obj ects', 'objects').replace('de nite', 'denote').replace('j ust', 'just')

# %%
stopwords_list = stopwords.words('english') + list(string.punctuation) + ['“','”','...',"''",'’','``', "'", "‘"]
custom_stopwords = ['–', 'also', 'something', 'cf', 'thus', 'two', 'now', 'would', 'make', 'eb', 'u', 'well', 'even', 'said', 'eg', 'us',
                    'n', 'sein', 'e', 'da', 'therefore', 'however', 'would', 'thing', 'must', 'merely', 'way', 'since', 'latter', 'first',
                    'B', 'mean', 'upon', 'yet', 'cannot', 'c', 'C', 'let', 'may', 'might', "'s", 'b', 'ofthe', 'p.', '_', '-', 'eg', 'e.g.',
                    'ie', 'i.e.', 'f', 'l', "n't", 'e.g', 'i.e', '—', '--', 'hyl', 'phil', 'one', 'press', 'cent', 'place'] + stopwords_list

# %%
cloud_dict = {}
for school in text_dict.keys():
    cloud_dict[school] = make_word_cloud(text_dict[school], custom_stopwords)
    cloud_dict['middle1'] = make_word_cloud('this page intentionally left blank', stopwords=[])
    cloud_dict['middle2'] = make_word_cloud('this page intentionally left blank', stopwords=[])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-12-3364729090.py in <cell line: 0>()
#       1 cloud_dict = {}
#       2 for school in text_dict.keys():
# ----> 3     cloud_dict[school] = make_word_cloud(text_dict[school], custom_stopwords)
#       4     cloud_dict['middle1'] = make_word_cloud('this page intentionally left blank', stopwords=[])
#       5     cloud_dict['middle2'] = make_word_cloud('this page intentionally left blank', stopwords=[])
#
# /gdrive/MyDrive/Colab Notebooks/functions.py in make_word_cloud(text, stopwords)
#     198                             max_words=30,
#     199                             stopwords=stopwords,
# --> 200                             color_func=lambda *args, **kwargs: (95,95,95)).generate(text)
#     201     return cloud
#     202
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate(self, text)
#     640         self
#     641         """
# --> 642         return self.generate_from_text(text)
#     643
#     644     def _check_generated(self):
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     622         """
#     623         words = self.process_text(text)
# --> 624         self.generate_from_frequencies(words)
#     625         return self
#     626
#
# /usr/local/lib/python3.11/dist-packages/wordcloud/wordcloud.py in generate_from_frequencies(self, frequencies, max_font_size)
#     408         frequencies = sorted(frequencies.items(), key=itemgetter(1), reverse=True)
#     409         if len(frequencies) <= 0:
# --> 410             raise ValueError("We need at least 1 word to plot a word cloud, "
#     411                              "got %d." % len(frequencies))
#     412         frequencies = frequencies[:self.max_words]
#
# ValueError: We need at least 1 word to plot a word cloud, got 0.

# %%
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6)) = plt.subplots(2, 3, figsize=(25, 14))

fig.suptitle('Word Clouds for Spiritual Traditions', size=40, fontweight='bold')
fig.tight_layout(rect=[0, 0, 1, 0.95])

ax1.imshow(cloud_dict['hinduism'])
ax1.set_title('Hinduism Word Cloud', size=25, pad=20, fontweight='bold')

ax2.imshow(cloud_dict['buddhism'])
ax2.set_title('Buddhism Word Cloud', size=25, pad=20, fontweight='bold')

ax3.imshow(cloud_dict['christianity'])
ax3.set_title('Christianity Word Cloud', size=25, pad=20, fontweight='bold')

ax4.imshow(cloud_dict['islam'])
ax4.set_title('Islam Word Cloud', size=25, pad=20, fontweight='bold')

ax5.imshow(cloud_dict['occult'])
ax5.set_title('Occult / Esotericism Word Cloud', size=25, pad=20, fontweight='bold')

ax6.imshow(cloud_dict['indigenous'])
ax6.set_title('Indigenous / Popol Vuh Word Cloud', size=25, pad=20, fontweight='bold')

for ax in fig.axes:
    ax.axis('off')

fig.patch.set_facecolor('#D1D1D1')
plt.show()

# %% [markdown]
# Note that these word clouds are the result of applying many custom stopwords. Those words were words that had significant overlap between schools and so could not be used to distinguish them.
#
# One of these common stopwards was the word 'one.' I guess Plato was right about it being the central concept of philosophy.
#
# Even after this pruning, a lot of the same words show up in all the schools. But there are also a good number of differences between the schools as well, enough that a model is not *prima facie* a lost cause.
#
# Our next step is to explore the frequency distrubtion of words in the corpus, both in the texts as a whole and in the individual schools.

# %%
all_texts_string = re.sub(r'[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\xff\xad\x0c6§\[\]\\\£\Â\n\r]', ' ', all_texts_string)
all_texts_string = re.sub(r'[0123456789]', ' ', all_texts_string)

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('punkt')
all_text_words = word_tokenize(all_texts_string)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
cleaned_words = [x.lower() for x in all_text_words if x.lower() not in custom_stopwords]
freq_dist = FreqDist(cleaned_words)

# %% [markdown]
# This more or less matches all the major topics of philosophy - ontology ('things'), human nature ('man'), logic and rationality ('reason'), truth ('true'), language ('say'). Of course these also reflect common turns of phrase in philosophical texts; these texts often discuss what is true and what others say, for example.
#
# Now let's take a look at frequency distributions for each school.

# %%
uninformative_words = ['else', 'shall', 'either', 'still', 'rather', 'another', 'made', 'without']
school_stopwords = custom_stopwords + [x[0] for x in freq_dist.most_common(50)] + uninformative_words

# %% [markdown]
# A lot of this is unsurprising - no one should be baffled that the word 'socrates' turns up a lot in Plato. Others are perhaps more interesting - the appearance of 'animal' in Aristotle, for example. And yet others are just artifacts of the texts we had available - the word 'madness' is common in Continental philosophy because of Foucault's book *History of Madness*. That said, some of these are comical as well. For example, analytic philosophy's tendency to logical formalism led to it having variables for propositions ('p' and 'x') among its most commonly used words.
#
# Still, these each seem substantially different enough that we should be able to build a reasonable model. Although we could leap to building a model right now, let's do a little more exploring by examining the bigrams.

# %%
# tokenizing the text to prepare it
pattern = "([a-zA-Z]+(?:'[a-z]+)?)"
all_tokens = nltk.regexp_tokenize(all_texts_string, pattern)

all_tokens_stopped = [x.lower() for x in all_tokens if x.lower() not in custom_stopwords]

# %% [markdown]
# While this isn't particularly informative, it does show us some common phrases used throughout the history of philosophy.
#
# Next we can create similar charts for each school to see which schools use which phrases preferentially.*italicized text*

# %%
import os, re
from collections import Counter
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS



# Prepare a base set of English stop words (and add a few old-fashioned terms)
stopwords = set(ENGLISH_STOP_WORDS)
# Optionally add domain-specific common words (archaic pronouns, etc.)
stopwords |= {"thou", "thee", "thy", "ye", "say", "said", "shall", "also", "could"}

for filename in os.listdir(folder_path):
    if not filename.lower().endswith(".txt"):
        continue
    filepath = os.path.join(folder_path, filename)
    with open(filepath, 'r', encoding='utf-8', errors='replace') as f:
        text = f.read()

    # Strip Gutenberg header/trailer if present
    start = text.find('*** START OF THIS PROJECT GUTENBERG')
    if start != -1:
        text = text[start:]
    end = text.find('*** END OF THIS PROJECT GUTENBERG')
    if end != -1:
        text = text[:end]

    # Lowercase and remove punctuation
    text = text.lower()
    # Replace punctuation with spaces (so words stay separated)
    text = re.sub(r'[\W_]+', ' ', text)

    # Tokenize into words
    tokens = re.findall(r'\b[a-z]+\b', text)

    # Filter out standard stop words
    tokens = [w for w in tokens if w not in stopwords]

    # Count word frequencies
    freq = Counter(tokens)

    # Take the top N frequent words as custom stop words (e.g., N=20)
    top_n = 20
    most_common = [word for word, count in freq.most_common(top_n)]

    print(f"{filename}: {most_common}")
# Out:
# yoga sutras patanjali.txt: ['spiritual', 'man', 'life', 'consciousness', 'mind', 'self', 'power', 'soul', 'things', 'powers', 'psychic', 'comes', 'psychical', 'nature', 'divine', 'come', 's', 'eternal', 'true', 'body']
# epistle to the son of the wolf.txt: ['god', 'hath', 'unto', 'o', 'lord', 'men', 'verily', 'things', 'wronged', 'world', 'day', 'earth', 'people', 'revelation', 'cause', 'saith', 'great', 'glory', 'truth', 'words']
# Bhagavad Gita.txt: ['self', 'brahman', 'man', 'o', 'world', 'food', 'mind', 'knows', 'breath', 'body', 'section', 'let', 'does', 'having', 'sun', 'knowledge', 'know', 'speech', 'earth', 'like']
# augustine city of god and christian doctrine.txt: ['god', 'things', 'man', 'men', 'gods', 's', 'good', 'life', 'body', 'christ', 'chapter', 'says', 'time', 'lord', 'great', 'soul', 'world', 'does', 'earth', 'death']
# Tao Te Ching.txt: ['tao', 'things', 'does', 'men', 'great', 'heaven', 'people', 'know', 'sage', 'state', 'like', 's', 'way', 'place', 'world', 'life', 'knows', 'death', 'earth', 'doing']
# Siri Guru Granth Sahib.txt: ['lord', 'guru', 'o', 's', 'true', 'god', 'nanak', 'mind', 'mehl', 'naam', 'pause', 'world', 'love', 'shabad', 'grace', 'word', 'peace', 'har', 'fifth', 'does']
# Analects.txt: ['master', 'chap', 'man', 'tsze', 'virtue', 'ch', 'asked', 'people', 'superior', 'men', 'yu', 'kung', 'confucius', 'does', 'lu', 'did', 'government', 'replied', 'good', 'things']
# Tanakh.txt: ['lord', 'unto', 'god', 'israel', 'king', 'son', 'land', 'man', 'house', 'hath', 'people', 'children', 'came', 'shalt', 'day', 's', 'hand', 'come', 'men', 'sons']
# kitab i ilqan book of certitude.txt: ['god', 'hath', 'unto', 'divine', 'people', 'qur', 'knowledge', 'truth', 'day', 'revelation', 'heaven', 'revealed', 'words', 'men', 'things', 'manifest', 'light', 'sun', 'earth', 'book']
# Knowledge of the Higher Worlds - by Rudolf Steiner.txt: ['world', 'life', 'higher', 'student', 'soul', 'spiritual', 'knowledge', 'physical', 'way', 'body', 'inner', 'thought', 'human', 'development', 'feeling', 'training', 'things', 'certain', 'sense', 'man']
# nature-gods.txt: ['gods', 'nature', 'things', 'world', 'reason', 'men', 'deity', 'man', 'earth', 'called', 'mind', 'great', 'form', 'says', 'divine', 'stars', 'like', 'think', 'sun', 'does']
# Kaivalya_Upanishad.txt: ['absolute', 'consciousness', 'self', 'knowledge', 'truth', 'existence', 'duality', 'creation', 'experience', 'desire', 'sage', 'reality', 'state', 'material', 'means', 'eternal', 'solitary', 'meaning', 'realisation', 'non']
# Kybalion.txt: ['mental', 'principle', 'mind', 'plane', 'hermetic', 'universe', 'matter', 'great', 'law', 'higher', 'life', 'planes', 'teachings', 'phenomena', 'energy', 'nature', 'man', 'truth', 'degree', 'kybalion']
# Collected Fruits of Occult Teaching by A.P.Sinnett (1920).txt: ['life', 'physical', 'world', 'human', 'nature', 'great', 'divine', 'time', 'people', 'knowledge', 'spiritual', 'progress', 'consciousness', 'idea', 'way', 'higher', 'astral', 's', 'conditions', 'occult']
# Secret Teachings of the Society of Jesus.txt: ['society', 'necessary', 'having', 'secret', 'great', 'instructions', 'jesus', 'jesuits', 'wisdom', 'little', 'bank', 'box', 'louisville', 'ky', 'fathers', 'make', 'princes', 'jesuit', 'persons', 'widows']
# wov.txt: ['man', 'p', 'good', 'brahmin', 'wise', 'evil', 'let', 'mind', 'world', 'lust', 'law', 'nirvana', 's', 'life', 'men', 'like', 'sorrow', 'death', 'come', 'bhikkhu']
# The Life of Buddha.txt: ['master', 'king', 'p', 's', 'o', 'buddha', 'day', 'prince', 'man', 'son', 'blessed', 'great', 'world', 'city', 'know', 'like', 'saw', 'law', 'father', 'come']
# dhammapada.txt: ['man', 'like', 'world', 'evil', 'let', 'good', 'wise', 'brahmana', 'does', 'free', 'law', 'mind', 'men', 'life', 'pain', 'people', 'body', 'knowledge', 'bhikshu', 'nirvana']
# Popol Vuh.txt: ['lords', 'called', 'did', 'balam', 'came', 'xibalba', 'went', 'boys', 'people', 'come', 'vucub', 'let', 'tribes', 'men', 'tohil', 'great', 'house', 'hun', 'earth', 'grandmother']
# tpol.txt: ['p', 'thought', 's', 'creatures', 'world', 'spirit', 'body', 'like', 'life', 'enlightenment', 'man', 'come', 'love', 'happiness', 'buddha', 'self', 'desire', 'beings', 'win', 'death']
# The Kitab I Aqdas.txt: ['god', 'baha', 'hath', 'llah', 'u', 's', 'lord', 'justice', 'unto', 'house', 'o', 'prayer', 'obligatory', 'book', 'aqdas', 'people', 'question', 'verily', 'world', 'answer']
# Advaita_Vedanta.txt: ['brahman', 'lord', 'self', 'world', 'truth', 'nature', 'knowledge', 'knower', 'body', 'consciousness', 'individual', 'non', 'says', 'upanishad', 'does', 'mind', 'field', 'teaching', 'verse', 'liberation']
# vedic_hymns_readable.txt: ['passage', 'agni', 'o', 'maruts', 'note', 'like', 'gods', 'indra', 'verse', 'sacrifice', 's', 'veda', 'meaning', 'heaven', 'p', 'soma', 'earth', 'god', 'hymn', 'men']
# vendanta sutras patanjali.txt: ['brahman', 'self', 'knowledge', 'soul', 'non', 'highest', 'text', 'nature', 'world', 'e', 'body', 'texts', 'different', 'means', 'individual', 'things', 'c', 'cause', 'meditation', 'does']
# gathas zoroastrianism.txt: ['o', 'verse', 'mazda', 'truth', 'ahura', 'lord', 'life', 'asha', 'wisdom', 'vohuman', 'good', 'people', 'love', 'pure', 'faith', 'world', 'grant', 'evil', 'persons', 'mind']
# revised.txt: ['number', 'remove', 'capitals', 'clean', 'chapter', 'uncleaned', 'sutras', 'patanjali', 'leave', 'space', 'instead', 'upanishad', 'c', 'names', 'verse', 'roman', 'book', 'csv', 'format', 'vedanta']

# %%
# custom stopwords for each school since there are odd phrases in each
stopwords_dict = {
    # Christianity
    'christianity': [
        'god', 'man', 'lord', 'christ', 'life', 'soul', 'world', 'earth', 'men', 'great'
    ],

    # Vedanta / Hinduism
    'hinduism': [
        'brahman', 'self', 'knowledge', 'soul', 'world', 'body', 'meditation', 'nature', 'truth', 'atman'
    ],

    # Islam / Quran
    'islam': [
        'god', 'lord', 'people', 'prophet', 'quran', 'day', 'revelation', 'truth', 'believe', 'mercy'
    ],

    # Buddhism
    'buddhism': [
        'buddha', 'life', 'man', 'monk', 'law', 'sacred', 'mind', 'spiritual', 'time', 'body'
    ],

    # Judaism / Kabbalah
    'judaism_kabbalah': [
        'god', 'world', 'holy', 'light', 'torah', 'israel', 'rabbi', 'king', 'blessed', 'genesis'
    ],

    # Zoroastrianism
    'zoroastrianism': [
        'man', 'life', 'world', 'god', 'mazda', 'spirit', 'soul', 'earth', 'righteousness', 'evil'
    ],

    # Indigenous
    'indigenous': [
        'lords', 'people', 'men', 'earth', 'great', 'tribes', 'house', 'came', 'called', 'balam'
    ],

    # Occult / Esoteric
    'occult': [
        'life', 'world', 'spiritual', 'knowledge', 'divine', 'nature', 'energy', 'time', 'people', 'great'
    ],

    # Modern Spirituality
    'modern_spirituality': [
        'life', 'energy', 'nature', 'water', 'earth', 'temperature', 'natural', 'forest', 'oxygen', 'quality'
    ]
}




# building the bigrams for each school
bigram_dict = {}
for school in text_dict.keys():
    tokens = nltk.regexp_tokenize(text_dict[school], pattern)
    tokens_stopped = [x.lower() for x in tokens if x.lower() not in (custom_stopwords + stopwords_dict[school])]
    measures = BigramAssocMeasures()
    finder = BigramCollocationFinder.from_words(tokens_stopped)
    scored = finder.score_ngrams(measures.raw_freq)
    bigram_dict[school] = scored
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-19-4005020347.py in <cell line: 0>()
#      54 for school in text_dict.keys():
#      55     tokens = nltk.regexp_tokenize(text_dict[school], pattern)
# ---> 56     tokens_stopped = [x.lower() for x in tokens if x.lower() not in (custom_stopwords + stopwords_dict[school])]
#      57     measures = BigramAssocMeasures()
#      58     finder = BigramCollocationFinder.from_words(tokens_stopped)
#
# /tmp/ipython-input-19-4005020347.py in <listcomp>(.0)
#      54 for school in text_dict.keys():
#      55     tokens = nltk.regexp_tokenize(text_dict[school], pattern)
# ---> 56     tokens_stopped = [x.lower() for x in tokens if x.lower() not in (custom_stopwords + stopwords_dict[school])]
#      57     measures = BigramAssocMeasures()
#      58     finder = BigramCollocationFinder.from_words(tokens_stopped)
#
# KeyError: 'bahai'

# %% [markdown]
# Not bad! These bigrams actually give a solid sense of the key concepts of some of the schools. Rationalism's emphasis on 'clear and distinct ideas' and empiricism's focus on 'simple and complex ideas' are so forceful that both singular and plural versions of the phrases show up. Heidegger's common phrase 'always already' finds itself on the Phenomenology bigram list, and the German Idealist's continual discussion of self-consciousness is also evident. Aristotle and Plato's bigrams are harder to interpret, with Plato's being mostly common locutions from the dialogues rather than anything philosophically significant.

# %% [markdown]
# ### More In-Depth Cleaning
#
# All the previous explorations were done with some basic cleaning methods like removing stopwords. And while we brushed over it thus far, in the process of dealing with the data we encountered a lot of oddities. These include
# - words fused together (e.g., 'aconcept' for 'a concept')
# - headers of pages occurring repeatedly in the text
# - page numbers and citation numbers
# - footnotes, roman numerals, titles of chapters
#
# All these would need to be removed if we are to train a model on the actual content of these thinkers, and especially if we want a neural network to do any kind of predictive work where it will look at full sentences.
#
# The process of dealing with these and getting the data ready for our models has a few steps:
# 1. develop a general cleaning function that can work for every text (removing roman numerals, for example)
# 2. examine each text itself and remove the specific headers that are relevant to it
#   - look for features that could capture all the footnotes here as well
# 3. tokenize the text using spacy
# 4. examine the tokens for unusual patterns
#   - there should be virtually no duplicate sentences
#   - we can remove sentences that are too short to mean anything
#   - remove sentences that contain terms that must be from footnotes (the author's name should be very rare in the actual text, for example)
#
# Unfortunately many of these steps can only be done ad hoc; there is no real way to know whether and what headers are in a text without examining the files individually. So the process is a bit tedious and time-consuming. Still, when we finish we will have data that is much cleaner and more useful for modeling.

# %% [markdown]
# #### 1. Universal Cleaning Steps

# %%
def baseline_clean(to_correct, capitals=True, bracketed_fn=False, odd_words_dict={}):
    # remove utf8 encoding characters and expanded special characters
    result = re.sub(r'[\x00-\x08\x0b\x0c\x0e-\x1f\x7f-\xff\xad\x0c6§\\\£\Â*_<>""⎫•{}Γ~]', ' ', to_correct)

    # remove additional special characters and symbols
    result = re.sub(r'[©®™†‡§¶•‰¿¡÷±≠≤≥∞∑∏√∫∂∆∇Ω∪∩⊂⊃⊄⊅∈∉∅∀∃∧∨¬→←↑↓↔⇄⇒⇐⇑⇓⇔]', ' ', result)

    # remove mathematical and scientific symbols
    result = re.sub(r'[αβγδεζηθικλμνξοπρστυφχψωΑΒΓΔΕΖΗΘΙΚΛΜΝΞΟΠΡΣΤΥΦΧΨΩ]', ' ', result)

    # remove currency symbols
    result = re.sub(r'[¢€¥₹₽₩₨₪₫₡₢₵₶₷₸₹₺₻₼₽₾₿]', ' ', result)

    # remove various dashes and hyphens
    result = re.sub(r'[\u2014\u2013\u2012\u2010\u2011\u2015\u2500-\u257F-]', ' ', result)

    # remove quotation marks and similar
    result = re.sub(r'[„‹›«»¨´`^¸˜˚˙¨¯˘˙˚¸˝˛ˇ]', ' ', result)

    # remove box drawing and block elements
    result = re.sub(r'[\u2500-\u257F\u2580-\u259F]', ' ', result)

    # remove geometric shapes
    result = re.sub(r'[\u25A0-\u25FF\u2600-\u26FF\u2700-\u27BF]', ' ', result)

    # remove arrows and miscellaneous symbols
    result = re.sub(r'[\u2190-\u21FF\u2900-\u297F]', ' ', result)

    # remove superscript and subscript numbers/letters
    result = re.sub(r'[⁰¹²³⁴⁵⁶⁷⁸⁹⁺⁻⁼⁽⁾ⁿ₀₁₂₃₄₅₆₇₈₉₊₋₌₍₎]', ' ', result)

    # remove fractions and special numeric characters
    result = re.sub(r'[½⅓⅔¼¾⅛⅜⅝⅞⅟]', ' ', result)

    # replace whitespace characters with actual whitespace
    result = re.sub(r'\s', ' ', result)

    # replace odd quotation marks with a standard
    result = re.sub(r'[''""]', "'", result)

    # replace the ﬀ, ﬃ and ﬁ with the appropriate counterparts
    result = re.sub(r'ﬀ', 'ff', result)
    result = re.sub(r'ﬁ', 'fi', result)
    result = re.sub(r'ﬃ', 'ffi', result)
    result = re.sub(r'ﬂ', 'fl', result)
    result = re.sub(r'ﬄ', 'ffl', result)

    # remove or standardize some recurring common and meaningless words/phrases
    result = re.sub(r'\s*This\s*page\s*intentionally\s*left\s*blank\s*', ' ', result)
    result = re.sub(r'(?i)Aufgabe\s+', ' ', result)
    result = re.sub(r',*\s+cf\.', ' ', result)

    # some texts have footnotes conveniently in brackets - this removes them all,
    # with a safety measure for unpaired brackets, and deletes all brackets afterwards
    if bracketed_fn:
        result = re.sub(r'\[.{0,300}\]|{.{0,300}}|{.{0,300}\]|\[.{0,300}}', ' ', result)
    result = re.sub(r'[\[\]{}]', ' ', result)

    # unify some abbreviations
    result = re.sub(r'&', 'and', result)
    result = re.sub(r'\se\.g\.\s', ' eg ', result)
    result = re.sub(r'\si\.e\.\s', ' ie ', result)
    result = re.sub('coroll\.', 'coroll', result)
    result = re.sub('pt\.', 'pt', result)

    # remove roman numerals, first capitalized ones
    result = re.sub(r'\s((I{2,}V*X*\.*)|(IV\.*)|(IX\.*)|(V\.*)|(V+I*\.*)|(X+L*V*I*]\.*))\s', ' ', result)
    # then lowercase
    result = re.sub(r'\s((i{2,}v*x*\.*)|(iv\.*)|(ix\.*)|(v\.*)|(v+i*\.*)|(x+l*v*i*\.*))\s', ' ', result)

    # remove periods and commas flanked by numbers
    result = re.sub(r'\d\.\d', ' ', result)
    result = re.sub(r'\d,\d', ' ', result)

    # remove the number-letter-number pattern used for many citations
    result = re.sub(r'\d*\w{,2}\d', ' ', result)

    # remove numerical characters
    result = re.sub(r'\d+', ' ', result)

    # remove words of 2+ characters that are entirely capitalized
    # (these are almost always titles, headings, or speakers in a dialogue)
    # remove capital I's that follow capital words - these almost always roman numerals
    # some texts do use these capitalizations meaningfully, so we make this optional
    if capitals:
        result = re.sub(r'[A-Z]{2,}\s+I', ' ', result)
        result = re.sub(r'[A-Z]{2,}', ' ', result)

    # remove isolated colons and semicolons that result from removal of titles
    result = re.sub(r'\s+:\s*', ' ', result)
    result = re.sub(r'\s+;\s*', ' ', result)

    # remove isolated letters (do it several times because strings of isolated letters do not get captured properly)
    for _ in range(6):
        result = re.sub(r'\s[^aAI\.]\s', ' ', result)

    # remove isolated letters at the end of sentences or before commas
    result = re.sub(r'\s[^aI]\.', '.', result)
    result = re.sub(r'\s[^aI],', ',', result)

    # deal with spaces around periods and commas
    result = re.sub(r'\s+,\s+', ', ', result)
    result = re.sub(r'\s+\.\s+', '. ', result)

    # remove empty parentheses
    result = re.sub(r'(\(\s*\.*\s*\))|(\(\s*,*\s*)\)', ' ', result)

    # reduce multiple periods, commas, or whitespaces into a single one
    result = re.sub(r'\.+', '.', result)
    result = re.sub(r',+', ',', result)
    result = re.sub(r'\s+', ' ', result)

    # deal with isolated problem cases discovered in the data:
    for key in odd_words_dict.keys():
        result = re.sub(r''+key+'', odd_words_dict[key], result)

    return result.strip()

# %% [markdown]
# This step is relatively easy - all we had to do was use regex to capture and remove the patterns that we needed to remove.
#
# The next step requires deeper examination of the individual texts, however.

# %% [markdown]
# #### 2. Text-by-Text Cleaning

# %% [markdown]
# In this step we will remove headers and other offensive features of specific texts.
#
# The most common problem the presence of headings that appear at the top of each page in the original book. When converted to a string, these then get interpolated into the text, interrupting the normal flow of sentences (this happens for page numbers and citations as well, but in those cases is much easier to deal with).
#
# To deal with this, we build a list of the headers for each book and then delete them from the string that represents the book. In the process, we may create some issues if the header is common, so we are careful to only delete when the loss is worth it.
#
# In some cases, of course, the texts are already clean and no extra steps are required.

# %% [markdown]
# #### 3. Tokenizing and Rendering the Texts as a Dataframe

# %% [markdown]
# We now are in a position to apply these methods to each text and return a dataframe for each of them. Although we are interested primarily in the schools of thought in general, it would be convenient and more useful for future projects if we also include the specific authors and titles.
#
# To prepare for this project, we build a dictionary for each school, so that we can then iterate over a list of dictionaries to create a dataframe for each.

# %%
# prepare lists that will be zipped into a dictionary

# texts


title_list = [
    "Advaita Vedanta",
    "Analects",
    "Bhagavad Gita",
    "Collected Fruits of Occult Teaching by A.P.Sinnett",
    "Kaivalya Upanishad",
    "Knowledge of the Higher Worlds - by Rudolf Steiner",
    "Kybalion",
    "Popol Vuh",
    "Secret Teachings of the Society of Jesus",
    "Siri Guru Granth Sahib",
    "Tanakh",
    "Tao Te Ching",
    "The Kitab I Aqdas",
    "The Life of Buddha",
    "Augustine City of God and Christian Doctrine",
    "Dhammapada",
    "Epistle to the Son of the Wolf",
    "Gathas Zoroastrianism",
    "Kitab I Ilqan Book of Certitude",
    "Nature Gods",
    "The Path of Light (TPOL)",
    "Vedic Hymns Readable",
    "Vedanta Sutras Patanjali",
    "Words of Virtue (WOV)",
    "Yoga Sutras Patanjali"
]

school_list = [
    'hinduism',         # Advaita Vedanta
    'confucianism',     # Analects
    'hinduism',         # Bhagavad Gita
    'occult_esoteric',  # Collected Fruits of Occult Teaching by A.P.Sinnett
    'hinduism',         # Kaivalya Upanishad
    'occult_esoteric',  # Knowledge of the Higher Worlds - by Rudolf Steiner
    'occult_esoteric',  # Kybalion
    'indigenous',       # Popol Vuh
    'christianity',     # Secret Teachings of the Society of Jesus
    'sikhism',          # Siri Guru Granth Sahib
    'judaism',          # Tanakh
    'taoism',           # Tao Te Ching
    'bahai',            # The Kitab I Aqdas
    'buddhism',         # The Life of Buddha
    'christianity',     # Augustine City of God and Christian Doctrine
    'buddhism',         # Dhammapada
    'bahai',            # Epistle to the Son of the Wolf
    'zoroastrianism',   # Gathas Zoroastrianism
    'bahai',            # Kitab I Ilqan Book of Certitude
    'occult_esoteric',  # Nature Gods
    'buddhism',         # The Path of Light (TPOL)
    'hinduism',         # Vedic Hymns Readable
    'hinduism',         # Vedanta Sutras Patanjali
    'occult_esoteric',  # Words of Virtue (WOV)
    'hinduism'          # Yoga Sutras Patanjali
]






# check lengths to make sure all are present
len(title_list), len(school_list), len(all_texts)
# Out:
# (25, 25, 25)

# %%
# combine all these into a single list of dictionaries
book_dicts = []
for i in range(0, 25):
  book_dict = {}
  book_dict['title'] = title_list[i].title()
  book_dict['text'] = all_texts[i]
  book_dict['school'] = school_list[i]
  book_dict['remove capitals'] = True
  book_dict['bracketed fn'] = False
  book_dicts.append(book_dict)



# check length again to make sure
len(book_dicts)
# Out:
# 25

# %% [markdown]
# With a dictionary for each text, we are prepared to clean them, build dataframes for each text, and combine them into a master dataframe for all our data.

# %%
#@title Oddities Dictionary for Cleaning
# a dictionary of oddities to clean up
odd_words_dict = {'\sderstanding': 'derstanding',
                  '\sforthe\s': ' for the ',
                  '\sject': 'ject',
                  '\sjects': 'jects',
                  '\sness': 'ness',
                  '\sper\scent\s': ' percent ',
                  '\sper\scent\.': ' percent.',
                  '\sper\scent,': ' percent,',
                  '\wi\son': 'ion',
                  '\spri\sori': ' priori',
                  '\stences\s': 'tences ',
                  '\sprincipleb': ' principle',
                  '\ssciousness': 'sciousness',
                  '\stion': 'tion',
                  '\spri\s': ' pri',
                  '\scluding': 'cluding',
                  '\sdom': 'dom',
                  '\sers': 'ers',
                  '\scritiq\s': ' critique ',
                  '\ssensati\s': ' sensation ',
                  '(?i)\syou\sll': " you'll",
                  '\sI\sll': " I'll",
                  '(?i)\swe\sll': " we'll",
                  '(?i)he\sll': " he'll",
                  '(?i)who\sll': "who'll",
                  '(?i)\sthere\sll\s': " there'll ",
                  '\seduca\s': ' education ',
                  '\slity\s': 'lity ',
                  '\smultaneously\s': 'multaneously ',
                  '\stically\s': 'tically ',
                  '\sDa\ssein\s': ' Dasein ',
                  '(?i)\sthey\sll\s': " they'll ",
                  '(?i)\sin\tum\s': ' in turn ',
                  '\scon~\s': ' con',
                  '\sà\s': ' a ',
                  '\sjor\s': ' for ',
                  '\sluminating\s': 'luminating ',
                  '\sselj\s': ' self ',
                  '\stial\s': 'tial ',
                  '\sversal\s': 'versal ',
                  '\sexis\st': ' exist',
                  '\splauded\s': 'plauded ',
                  '\suiry\s': 'uiry ',
                  '\svithin\s': ' within ',
                  '\soj\s': ' of ',
                  '\sposi\st': ' posit',
                  '\sra\sther\s': ' rather ',
                  '(?i)\sthat\sll\s': " that'll ",
                  '(?i)\sa\sll\s': ' all ',
                  '\so\sther\s': ' other ',
                  '\sra\sther\s': ' rather ',
                  '\snei\sther\s': ' neither ',
                  '\sei\sther\s': ' either ',
                  '\sfur\sther\s': ' further ',
                  '\sano\sther': ' another ',
                  '\sneces\s': ' neces',
                  'u\slar\s': 'ular ',
                  '\sference\s': 'ference ',
                  '(?i)it\sll\s': "it'll ",
                  '\stoge\sther': ' together ',
                  '\sknowledgeb\s': ' knowledge ',
                  'r\stain\s': 'rtain ',
                  'on\stain\s': 'ontain',
                  '(?i)j\sect\s': 'ject',
                  '\sob\sect\s': ' object ',
                  '\sbtle\s': 'btle ',
                  '\snition\s': 'nition ',
                  '\sdering\s': 'dering ',
                  '\sized\s': 'ized ',
                  '\sther\shand': ' other hand',
                  '\ture\s': 'ture ',
                  '\sabso\sl': ' absol',
                  '\stly\s': 'tly ',
                  '\serty\s': 'erty ',
                  '\sobj\se': ' obj',
                  '\sffiir\s': ' for ',
                  '\sndeed\s': ' indeed ',
                  '\sfonn\s': ' form ',
                  '\snally\s': 'nally ',
                  'ain\sty\s': 'ainty ',
                  'ici\sty\s': 'icity ',
                  '\scog\sni': ' cogni',
                  '\sacc\s': ' acc',
                  '\sindi\svid\sual': ' individual',
                  '\sintu\sit': ' intuit',
                  'r\sance\s': 'rance ',
                  '\ssions\s': 'sions ',
                  '\sances\s': 'ances ',
                  '\sper\sception\s': ' perception ',
                  '\sse\sries\s': ' series ',
                  '\sque\sries\s': ' queries ',
                  '\sessary\s': 'essary ',
                  '\sofa\s': ' of a ',
                  '\scer\stainty\s': ' certainty ',
                  'ec\stivity\s': 'ectivity ',
                  '\stivity\s': 'tivity ',
                  '\slation\s': 'lation ',
                  '\sir\sr': ' irr',
                  '\ssub\sstance\s': ' substance ',
                  'sec\sond\s': 'second ',
                  '\s\.rv': '',
                  '\story\s': 'tory ',
                  '\sture\s': 'ture ',
                  '\sminate\s': 'minate ',
                  '\sing\s': 'ing ',
                  '\splicity\s': 'plicity ',
                  '\ssimi\slar\s': ' similar ',
                  '\scom\smunity\s': ' community ',
                  '\sitselfa\s': ' itself a ',
                  '\ssimp\s': ' simply ',
                  '\scon\stex': ' contex',
                  '\scon\sseq': ' conseq',
                  '\scon\stai': ' contai',
                  '\sofwhat\s': ' of what ',
                  '\sui\s': 'ui',
                  '\sofan\s': ' of an ',
                  '\saccor\sdance\s': ' accordance ',
                  '\stranscen\sdental\s': ' transcendental ',
                  '\sap\spearances\s': ' appearances ',
                  'e\squences\s': 'equences ',
                  '\sorits\s': ' or its ',
                  '\simma\sn': ' imman',
                  '\seq\sua': ' equa',
                  '\simpl\sied\s': ' implied ',
                  '\sbuta\s': ' but a ',
                  '\sa\snd\s': ' and ',
                  '\sence\s': 'ence ',
                  '\stain\s': 'tain ',
                  '\sunder\sstanding\s': ' understanding ',
                  'i\sence\s': 'ience ',
                  'r\sence\s': 'rence ',
                  '\stical\s': 'tical ',
                  '\sobjectsb\s': ' objects ',
                  '\stbe\s': ' the ',
                  '\smul\st': ' mult',
                  '\sgen\seral\s': ' general ',
                  '\suniver\ssal\s': ' universal ',
                  '\scon\stent\s': ' content ',
                  '\spar\sticular\s': ' particular ',
                  'ver\ssity\s': 'versity ',
                  '\sCritiq\s': ' Critique ',
                  '\sphilo\ssophy\s': ' philosophy ',
                  '\seq\s': ' eq'}

# %%
import gc

# ✅ Fix: Missing parenthesis
def split_text(text, max_len=50_000):
    return [text[i:i+max_len] for i in range(0, len(text), max_len)]

def from_raw_to_df(text_dict):
    nlp.max_length = 14_000_000  # Still needed

    # Step 1: Clean text
    text = text_dict['text']
    text = baseline_clean(
        text,
        capitals=text_dict['remove capitals'],
        bracketed_fn=text_dict['bracketed fn'],
        odd_words_dict=odd_words_dict
    )

    # Step 2: Chunk the cleaned text and use SpaCy on each chunk
    chunks = split_text(text, max_len=50_000)

    # ✅ Efficient and RAM-safe: disable NER, tagger, parser
    docs = list(nlp.pipe(chunks, batch_size=1, disable=["ner"]))
    sentences = [s for doc in docs for s in doc.sents]

    # Step 3: Create DataFrame (avoid keeping spaCy Span objects)
    sentence_strs = [''.join(str(s)) for s in sentences]
    text_df = pd.DataFrame({
        'sentence_str': sentence_strs,
        'title': text_dict['title'],
        'school': text_dict['school'],
    })

    return text_df

# %%
df_list = []
for i, book in enumerate(book_dicts):
    print(f"Processing book {i+1}/{len(book_dicts)}: {book['title']}")
    book_df = from_raw_to_df(book)
    df_list.append(book_df)

    # ✅ Optional: Save each to disk
    # book_df.to_parquet(f"book_{i}.parquet")

    del book_df
    gc.collect()

df = pd.concat(df_list, ignore_index=True)
del df_list
gc.collect()
# Out:
# Processing book 1/25: Advaita Vedanta
# Processing book 2/25: Analects
# Processing book 3/25: Bhagavad Gita
# Processing book 4/25: Collected Fruits Of Occult Teaching By A.P.Sinnett
# Processing book 5/25: Kaivalya Upanishad
# Processing book 6/25: Knowledge Of The Higher Worlds - By Rudolf Steiner
# Processing book 7/25: Kybalion
# Processing book 8/25: Popol Vuh
# Processing book 9/25: Secret Teachings Of The Society Of Jesus
# Processing book 10/25: Siri Guru Granth Sahib
# Processing book 11/25: Tanakh
# Processing book 12/25: Tao Te Ching
# Processing book 13/25: The Kitab I Aqdas
# Processing book 14/25: The Life Of Buddha
# Processing book 15/25: Augustine City Of God And Christian Doctrine
# Processing book 16/25: Dhammapada
# Processing book 17/25: Epistle To The Son Of The Wolf
# Processing book 18/25: Gathas Zoroastrianism
# Processing book 19/25: Kitab I Ilqan Book Of Certitude
# Processing book 20/25: Nature Gods
# Processing book 21/25: The Path Of Light (Tpol)
# Processing book 22/25: Vedic Hymns Readable
# Processing book 23/25: Vedanta Sutras Patanjali
# Processing book 24/25: Words Of Virtue (Wov)
# Processing book 25/25: Yoga Sutras Patanjali
# 0

# %%
#@title
# ## some code for checking oddities

# # unfortunately it has to be done ad hoc and as they are discovered,
# # so we will not go too deep into it
# #
# # the code is commented out to make running the notebook smoother


# word_list = [
# 'tent',
# 'per',
# 'cent'
# 'imma']

# word_checker = pd.DataFrame()
# for word in word_list:
#   word_check_slice = df[(df['sentence_str'].str.contains('\s'+word+'\s'.lower()))].copy()
#   word_check_slice['word'] = word
#   word_checker = word_checker.append(word_check_slice)

# print(len(word_checker))
# print(len(word_list))
# word_checker['word'].value_counts()

# pd.options.display.max_colwidth = 300
# word_checker[word_checker['word']=='con']

# %% [markdown]
# And *voila*! There we have it. We can do some quick exploring to make sure everything came out ok, but we are nearing the end of our task!

# %%
pd.options.display.max_colwidth = 200
df.sample(10)
# Out:
#                                                                                                                                                                                                    sentence_str  \
# 163018                                                                                     The minister of crime of Ch'an asked whether the duke Chao knew propriety, and Confucius said, 'He knew propriety.'.
# 120648                                                                                                   || I sing the Glorious Praises of the unchanging, eternal Lord God, and the noose of death is snapped.
# 165819                                                                                                                                                                                        said Chamiaholom.
# 17317                                                                                                                  In the swooning person there is half combination; this being the remaining (hypothesis).
# 56668                            Thou shalt not wrest judgment; thou shalt not respect persons; neither shalt thou take gift; for gift doth blind the eyes of the wise, and pervert the words of the righteous.
# 39916                                                                                                                                                                               Gen. Gen. See Contra Faust.
# 90313                                                                                                                 || You shall not obtain this human body again; make the effort try to achieve liberation!
# 50555                                                Lift it up, be not afraid; say unto the cities of Judah: �Behold your God Behold the Lord God will come with strong hand, and His arm shall rule for Him.�
# 42543   As for those who, even though they know and understand my directions, fail to penetrate the meaning of obscure passages in Scripture, they may stand for those who, in the case I have imagined, are...
# 48489                                                                                                                            This prohibition was defined by Shoghi Effendi as plunging one�s hand in food.
#
#                                                      title           school
# 163018                               Gathas Zoroastrianism   zoroastrianism
# 120648                                          Dhammapada         buddhism
# 165819                                         Nature Gods  occult_esoteric
# 17317   Collected Fruits Of Occult Teaching By A.P.Sinnett  occult_esoteric
# 56668         Augustine City Of God And Christian Doctrine     christianity
# 39916                               Siri Guru Granth Sahib          sikhism
# 90313                                           Dhammapada         buddhism
# 50555                                   The Life Of Buddha         buddhism
# 42543                               Siri Guru Granth Sahib          sikhism
# 48489                                    The Kitab I Aqdas            bahai

# %%
df['school'].value_counts(normalize=True)
# Out:
# school
# buddhism           0.512070
# occult_esoteric    0.153275
# christianity       0.149912
# confucianism       0.048515
# sikhism            0.047941
# hinduism           0.038921
# bahai              0.022482
# taoism             0.012366
# zoroastrianism     0.009764
# indigenous         0.002783
# judaism            0.001971
# Name: proportion, dtype: float64

# %% [markdown]
# The texts look more or less ok, though there is still some cleaning to be done. And there is definitely some class imabalance (with 10 schools, ideally they'd each be at 10%).
#
# That said, the numbers look reasonable enough that we have something we can work with. We can even do some fun stuff like find the average length of a sentence for each school or run other little tests.

# %% [markdown]
# ### Cleaning the Dataframe

# %% [markdown]
# But before the fun EDA stuff, to ensure that we get good results, we need to clean the dataframe. This will take a few steps:
# 1. Determine a threshold length and cut the (so-called) sentences that are shorter than that length (this will already eliminate meaningless duplicates like punctuations)
# 2. Check for words that indicate footnotes (words like 'edition' or 'ibid'); we can then cut these sentences from the data
# 3. Check for duplicates; there should be few if any duplicates in the dataframe for each school
# 4. Check for words that indicate other languages so that we can eliminate quotations, citations, or other non-English sentences

# %% [markdown]
# #### 1. Deal with Short Sentences

# %%
df['sentence_length'] = df['sentence_str'].map(lambda x: len(x))
num_of_short_entries = len(df[df['sentence_length'] < 20])
print(f"there are {num_of_short_entries} so-called sentences with fewer than 20 characters")
df[df['sentence_length'] < 20].sample(5)
# Out:
# there are 35789 so-called sentences with fewer than 20 characters
#        sentence_str                                         title  \
# 121445           ||                                    Dhammapada
# 161066           ||                                    Dhammapada
# 117703           ||                                    Dhammapada
# 55393             �  Augustine City Of God And Christian Doctrine
# 82323            ||                                    Dhammapada
#
#               school  sentence_length
# 121445      buddhism                2
# 161066      buddhism                2
# 117703      buddhism                2
# 55393   christianity                1
# 82323       buddhism                2

# %% [markdown]
# Sentences with fewer than 20 characters tend to be more or less meaningless, so we will drop them.

# %%
df = df.drop(df[df['sentence_length'] < 20].index)
len(df)
# Out:
# 140261

# %% [markdown]
# #### 2. Look at Words that Indicate Footnotes

# %% [markdown]
# Now let's look at footnote-indicator words.

# %%
fn_words = ['ch\.', 'bk', 'sect\.', 'div\.', 'cf', 'ibid', 'prop\.', 'Q\.E\.D\.',
            'pt\.', 'coroll\.', 'cf\.']

df['sentence_lowered'] = df['sentence_str'].str.lower()

fn_df_list = []

for word in fn_words:
    found_word = df[df['sentence_lowered'].str.contains(r'\s' + word.lower(), regex=True)].copy()
    found_word['word'] = word
    fn_df_list.append(found_word)

fn_df = pd.concat(fn_df_list, ignore_index=True)

# %%
fn_df.sample(5)
# Out:
#                                                                                                                                                                                                sentence_str  \
# 8   For, as other scriptural texts testify ('Then he becomes united with the True,' Ch. Up. 'Embraced by the intelligent Self he knows nothing that is without, nothing that is within,' Bri, Up., the a...
# 25                                                                                                                                                                                 Rom. Cf. Cicero, Orator.
# 19                                                                                      Either thou must recognize it, or�God forbid�arise and deny all the Prophets Reflect, Shaykh, upon the Shi�ih sect.
# 13                                         the vidya of the five fires, and those who in the forest meditate on faith and austerity go to light,there is a person not human, he leads them to Brahman,' Ch.
# 12                                                                                                                          The case is analogous to that of the meditation on 'plenitude' (bhuman; Ch. Up.
#
#                                                  title           school  \
# 8   Collected Fruits Of Occult Teaching By A.P.Sinnett  occult_esoteric
# 25                              Siri Guru Granth Sahib          sikhism
# 19                                  The Life Of Buddha         buddhism
# 13  Collected Fruits Of Occult Teaching By A.P.Sinnett  occult_esoteric
# 12  Collected Fruits Of Occult Teaching By A.P.Sinnett  occult_esoteric
#
#     sentence_length  \
# 8               304
# 25               24
# 19              115
# 13              160
# 12               79
#
#                                                                                                                                                                                            sentence_lowered  \
# 8   for, as other scriptural texts testify ('then he becomes united with the true,' ch. up. 'embraced by the intelligent self he knows nothing that is without, nothing that is within,' bri, up., the a...
# 25                                                                                                                                                                                 rom. cf. cicero, orator.
# 19                                                                                      either thou must recognize it, or�god forbid�arise and deny all the prophets reflect, shaykh, upon the shi�ih sect.
# 13                                         the vidya of the five fires, and those who in the forest meditate on faith and austerity go to light,there is a person not human, he leads them to brahman,' ch.
# 12                                                                                                                          the case is analogous to that of the meditation on 'plenitude' (bhuman; ch. up.
#
#       word
# 8     ch\.
# 25    cf\.
# 19  sect\.
# 13    ch\.
# 12    ch\.

# %% [markdown]
# Unfortunately, there was too much noise and too many differences in how the sentences were tokenized, so this kind of cleaning did not prove useful. As can be seen above, many of the relevant terms were used in meaningful sentences attributable to the correct authors.
#
# We were able to tell that 'bk.' was almost never used productively, so we cut that. For others, this was instructive in helping us clean the text and making revisions to the baseline cleaning function.

# %% [markdown]
# #### 4. Deal with Duplicates

# %% [markdown]
# Now let's look at how many duplicates we have.

# %%
# find the total number of duplicates
len(df['sentence_str'])-len(df['sentence_str'].drop_duplicates())
# Out:
# 1890

# %%
# get the number of duplicates in each school
for school in df['school'].unique():
  print(school)
  print(len(df.loc[df['school'] == school]['sentence_str']) -
        len(df.loc[df['school'] == school]['sentence_str'].drop_duplicates()))
# Out:
# hinduism
# 50
# confucianism
# 457
# occult_esoteric
# 166
# indigenous
# 4
# christianity
# 254
# sikhism
# 3
# judaism
# 0
# taoism
# 5
# bahai
# 79
# buddhism
# 844
# zoroastrianism
# 7

# %%
doubles_df = pd.concat(g for _, g in df.groupby("sentence_str") if len(g) > 1)
doubles_df.sample(5)
# Out:
#                                                                                                     sentence_str  \
# 21874                                                            The gods have held Agni as the giver of wealth.
# 165804                                                                            What is it that has stung you?
# 127236                                                                                     Image Of The Undying.
# 92990   The Divine Guru is my companion, the Destroyer of ignorance; the Divine Guru is my relative and brother.
# 8242                                                                               They said: We did understand.
#
#                                                      title           school  \
# 21874   Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
# 165804                                         Nature Gods  occult_esoteric
# 127236                                          Dhammapada         buddhism
# 92990                                           Dhammapada         buddhism
# 8242                                              Analects     confucianism
#
#         sentence_length  \
# 21874                47
# 165804               30
# 127236               21
# 92990               104
# 8242                 29
#
#                                                                                                 sentence_lowered
# 21874                                                            the gods have held agni as the giver of wealth.
# 165804                                                                            what is it that has stung you?
# 127236                                                                                     image of the undying.
# 92990   the divine guru is my companion, the destroyer of ignorance; the divine guru is my relative and brother.
# 8242                                                                               they said: we did understand.

# %% [markdown]
# From this it is clear that many of these duplicates are notes, meaninglessly short, or else headings that somehow escaped earlier efforts. Oddly, an enormous number of aristotle's sentences seem to be doubled. Looking at the doubled sentences, this appears to be because similar notes were made in both of the two volumes of the text.
#
# Let's eliminate the aristotle doubles first, then take another look to see what the others are like.

# %% [markdown]
# Deeper exploration of the duplicates reveals that Kant has a lot of doubles that seem to be authentically from his texts. Plato also has several duplicate sentences, but these are almost all short phrases from the dialogues ('of course, yes' and that kind of thing).
#
# To preserve the Kant, while also removing the irrelevant duplicates, we will remove both copies of all duplicates from texts other than the Kant's *Critique of Pure Reason*. For that text, we will remove the short duplicates and keep one copy of the longer ones, thus preserving the meaningful sentences.

# %% [markdown]
# #### Check for Foreign-Language Sentences

# %% [markdown]
# With this cleared up, let's do a couple quick tests to check for other languages in our texts. We use 'der' to check for German, since it is a common article and is not an English word. Similarly 'il' can be used to check for French.

# %%
(df[df['sentence_str'].str.contains('\sder\s')]).sample(5)
# Out:
#                                                                                                                                                         sentence_str  \
# 28988  For other explanations see Roth, Uber gewisse Kurzungen, Wien, Bartholomae, in Kuhn's Zeitschrift, Schmidt, Die Pluralbildungen der indogermanischen Neutra,.
# 27110                                             Benfey: 'Dann stu'rzen reichlich aus der rothen (Gewitterwolke) Tropfen, mit Fluth wie eine Haut die Erde netzend.
# 29478                                                                                                                   Ludwig: 'Die sich nicht weigern der geburt.'
# 21367                                                                     The removal of yat has already been proposed by Bollensen (Zeitschrift der Deutschen Morg.
# 23696                                                I prefer to follow the opinion of Bechtel, Nachrichten der Gottinger Gesellschaft der Wissenschaften, philolog.
#
#                                                     title           school  \
# 28988  Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
# 27110  Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
# 29478  Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
# 21367  Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
# 23696  Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
#
#        sentence_length  \
# 28988              157
# 27110              114
# 29478               44
# 21367               90
# 23696              111
#
#                                                                                                                                                     sentence_lowered
# 28988  for other explanations see roth, uber gewisse kurzungen, wien, bartholomae, in kuhn's zeitschrift, schmidt, die pluralbildungen der indogermanischen neutra,.
# 27110                                             benfey: 'dann stu'rzen reichlich aus der rothen (gewitterwolke) tropfen, mit fluth wie eine haut die erde netzend.
# 29478                                                                                                                   ludwig: 'die sich nicht weigern der geburt.'
# 21367                                                                     the removal of yat has already been proposed by bollensen (zeitschrift der deutschen morg.
# 23696                                                i prefer to follow the opinion of bechtel, nachrichten der gottinger gesellschaft der wissenschaften, philolog.

# %%
len((df[df['sentence_str'].str.contains('\sder\s')]))
# Out:
# 47

# %%
mask = df['title'] == 'Augustine City Of God And Christian Doctrine'
df.loc[mask, 'sentence_str'] = df.loc[mask, 'sentence_str'].str.replace(r'^And\s+', '', regex=True)

# %%
import re

def remove_upanishad_citations(text):
    return re.sub(r'\(?[\w\s,]*?(?:Up\.|I,)[\w\s.,]*?\)?\s*\);?', '', text)

mask = df['title'] == 'Collected Fruits Of Occult Teaching By A.P.Sinnett'
df.loc[mask, 'sentence_str'] = df.loc[mask, 'sentence_str'].apply(remove_upanishad_citations)

# %% [markdown]
# These all seem questionable at best - the 'der' indicates a German phrase or book title where it doesn't just denote a fully German quote. Let's drop those and check 'il.'

# %%
df = df.drop(df[df['sentence_str'].str.contains('\sder\s')].index)

len(df)
# Out:
# 140214

# %%
df[df['sentence_str'].str.contains('\sil\s')].sample(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-41-1990141316.py in <cell line: 0>()
# ----> 1 df[df['sentence_str'].str.contains('\sil\s')].sample(5)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    6116             weights = sample.preprocess_weights(self, weights, axis)
#    6117
# -> 6118         sampled_indices = sample.sample(obj_len, size, replace, weights, rs)
#    6119         result = self.take(sampled_indices, axis=axis)
#    6120
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/sample.py in sample(obj_len, size, replace, weights, random_state)
#     150             raise ValueError("Invalid weights: weights sum to zero")
#     151
# --> 152     return random_state.choice(obj_len, size=size, replace=replace, p=weights).astype(
#     153         np.intp, copy=False
#     154     )
#
# numpy/random/mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# It seems clear that those using 'il' are predominantly notes in French, especially from Marx. We drop them; even those with some meaning must have some errors - 'il' is not an English word.

# %%
df = df.drop(df[df['sentence_str'].str.contains('\sil\s')].index)

len(df)
# Out:
# 140213

# %% [markdown]
# #### Some Ad Hoc Cleaning

# %% [markdown]
# These last cells show us cleaning up some things that we noticed as we read over the data and explored it in other ways. There is nothing systematic here, just us noticing bad data and deleting as we go.

# %%
# miscellaneous nonsense sentences
df = df.drop(df[df['sentence_str'].str.contains('\spp\s')].index)
df = df.drop(df[df['sentence_str'].str.contains('\stotam\s')].index)
df = df.drop(df[df['sentence_str'].str.contains('\srree\s')].index)
df = df.drop(df[df['sentence_str'].str.contains('\sflir\s')].index)
df = df.drop(df[df['sentence_str'].str.contains('\smodis\s')].index)

len(df)
# Out:
# 140213

# %%
# markers of french and notes
df = df.drop(df[df['sentence_str'].str.contains('\schapitre')].index)
df = df.drop(df[df['sentence_str'].str.contains('\salisme')].index)
df = df.drop(df[df['sentence_str'].str.contains('\sHahn')].index)

len(df)
# Out:
# 140213

# %%
# some notes in Kant
df = df.drop(df[df['sentence_str'].str.contains('\sVorl\s')].index)

len(df)
# Out:
# 140213

# %% [markdown]
# ### Lemmatizing, Tokenizing, and Exporting

# %% [markdown]
# This brings us to the end of our pruning the data. Let's take a quick look at how the schools break down after the cleaning.

# %%
df['school'].value_counts(normalize=True)
# Out:
# school
# buddhism           0.442284
# occult_esoteric    0.173700
# christianity       0.168408
# confucianism       0.056742
# sikhism            0.051151
# hinduism           0.048476
# bahai              0.027316
# taoism             0.014050
# zoroastrianism     0.011953
# indigenous         0.003459
# judaism            0.002461
# Name: proportion, dtype: float64

# %% [markdown]
# Things seem slightly more balanced, if only because there are a few thousand
# less sentences overall. At this point, we are ready to export the dataframe. Before doing so, we will make future work easier by adding adding two columns: one with lemmatized text and another with tokenized text.

# %% [markdown]
# One last preview before we finalize the document:

# %%
df.sample(5)
# Out:
#                                                                                                                                                                                                    sentence_str  \
# 100675                                                                                  He came and poured His Ambrosial Nectar into your hands, but it slipped through your fingers, and fell onto the ground.
# 119826                                                                                                                                                     He acts out in ego, and suffers terrible punishment.
# 53375                                                                                                                                                              he went out from Pharaoh, and entreated the.
# 49767   Shaykh Every time God the True One�exalted be His glory�revealed Himself in the person of His Manifestation, He came unto men with the standard of He doeth what He willeth, and ordaineth what He p...
# 24215                                                                                                                      Men have set down Agni as the Hotri, the Usigs, honouring (him), the praise of Ayu .
#
#                                                      title           school  \
# 100675                                          Dhammapada         buddhism
# 119826                                          Dhammapada         buddhism
# 53375         Augustine City Of God And Christian Doctrine     christianity
# 49767                                   The Life Of Buddha         buddhism
# 24215   Knowledge Of The Higher Worlds - By Rudolf Steiner  occult_esoteric
#
#         sentence_length  \
# 100675              119
# 119826               52
# 53375                48
# 49767               204
# 24215                84
#
#                                                                                                                                                                                                sentence_lowered
# 100675                                                                                  he came and poured his ambrosial nectar into your hands, but it slipped through your fingers, and fell onto the ground.
# 119826                                                                                                                                                     he acts out in ego, and suffers terrible punishment.
# 53375                                                                                                                                                          and he went out from pharaoh, and entreated the.
# 49767   shaykh every time god the true one�exalted be his glory�revealed himself in the person of his manifestation, he came unto men with the standard of he doeth what he willeth, and ordaineth what he p...
# 24215                                                                                                                      men have set down agni as the hotri, the usigs, honouring (him), the praise of ayu .

# %% [markdown]
# Looks good! Let's export.

# %%
import re
from typing import List, Set, Iterable
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import spacy

DEFAULT_CAPITAL_WHITELIST = {"God", "Truth", "Love", "Justice", "Wisdom", "LORD"}
DEFAULT_ENTITY_LABELS = {"PERSON", "GPE", "ORG", "DATE"}

def load_spacy_model(model_name: str = "en_core_web_sm"):
    """Load a spaCy model, with error handling."""
    try:
        return spacy.load(model_name)
    except OSError:
        raise RuntimeError(f"spaCy model '{model_name}' not found. Run: python -m spacy download {model_name}")

def capital_ratio(
    sentence: str,
    whitelist: Set[str] = DEFAULT_CAPITAL_WHITELIST,
    threshold: float = 0.3,
    min_word_len: int = 3
) -> bool:
    """
    Returns True if the ratio of capitalized words (not in whitelist) exceeds threshold.
    """
    words = [w for w in word_tokenize(sentence) if w.isalpha() and len(w) >= min_word_len]
    if not words:
        return False
    capitalized = [
        w for i, w in enumerate(words)
        if w[0].isupper() and w not in whitelist and i != 0
    ]
    ratio = len(capitalized) / len(words)
    return ratio >= threshold

def is_mostly_named_entities(
    sentences: Iterable[str],
    nlp,
    entity_labels: Set[str] = DEFAULT_ENTITY_LABELS,
    max_entity_ratio: float = 0.4
) -> List[bool]:
    """
    Returns a list of bools indicating if each sentence is mostly named entities.
    """
    results = []
    for doc in nlp.pipe(sentences, disable=["tagger", "parser"]):
        if len(doc) == 0:
            results.append(False)
            continue
        entity_tokens = set()
        for ent in doc.ents:
            if ent.label_ in entity_labels:
                entity_tokens.update(range(ent.start, ent.end))
        ratio = len(entity_tokens) / len(doc)
        results.append(ratio >= max_entity_ratio)
    return results

def contains_philosophical_terms(sentence: str, keywords: Set[str]) -> bool:
    """Check if any keyword is present in the sentence (case-insensitive)."""
    sentence_lower = sentence.lower()
    return any(k in sentence_lower for k in keywords)

def sentence_is_useful(
    sentence: str,
    keywords: Set[str],
    cap_threshold: float = 0.3,
    min_len: int = 8,
    whitelist: Set[str] = DEFAULT_CAPITAL_WHITELIST
) -> bool:
    """
    Returns True if the sentence is long enough and not mostly capitalized (unless it contains a keyword).
    """
    if len(sentence.split()) < min_len:
        return False
    if capital_ratio(sentence, whitelist=whitelist, threshold=cap_threshold) and not contains_philosophical_terms(sentence, keywords):
        return False
    return True

def clean_sentences(
    sentences: List[str],
    keywords: Set[str],
    nlp=None,
    cap_threshold: float = 0.3,
    min_len: int = 8,
    entity_labels: Set[str] = DEFAULT_ENTITY_LABELS,
    diagnostics: bool = False
) -> List[str]:
    """
    Filter sentences by capital ratio, length, and named entity ratio.
    """
    if nlp is None:
        nlp = load_spacy_model()
    filtered = [
        s for s in sentences
        if sentence_is_useful(s, keywords, cap_threshold, min_len)
    ]
    entity_flags = is_mostly_named_entities(filtered, nlp, entity_labels)
    final = [s for s, flag in zip(filtered, entity_flags) if not flag]
    if diagnostics:
        print(f"Original: {len(sentences)}, After capital/length: {len(filtered)}, After NER: {len(final)}")
    return final

# %%
from google.colab import drive
from google.colab import files
import pandas as pd

# Mount Google Drive
print("Mounting Google Drive...")
drive.mount('/content/drive')

# Save your current dataframe first
df.to_csv('reli_nlp.csv', index=False)

# Read Bible and Quran data from Google Drive with correct paths
try:
    bible_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/religion/bible_data_set.csv')
    print(f"Bible data loaded successfully: {len(bible_df)} rows")
    print(f"Bible columns: {bible_df.columns.tolist()}")
except FileNotFoundError:
    print("Bible file not found. Check the path: /content/drive/MyDrive/Colab Notebooks/religion/bible_data_set.csv")
    bible_df = None

try:
    quran_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/religion/quran.csv')
    print(f"Quran data loaded successfully: {len(quran_df)} rows")
    print(f"Quran columns: {quran_df.columns.tolist()}")
except FileNotFoundError:
    print("Quran file not found. Check the path: /content/drive/MyDrive/Colab Notebooks/religion/quran.csv")
    quran_df = None

# Check if df has the right column
print(f"Main df columns: {df.columns.tolist()}")

# Rename columns in main df if needed
if 'sentence_str' in df.columns:
    df = df.rename(columns={'sentence_str': 'text'})

# Create list of dataframes to concatenate
dfs_to_concat = [df]

# Process Bible data if available
if bible_df is not None:
    # Add required columns
    if 'school' not in bible_df.columns:
        bible_df['school'] = 'christianity'
    if 'source' not in bible_df.columns:
        bible_df['source'] = 'bible'

    # Bible already has 'text' column - no renaming needed

    # Select only the columns you need
    columns_to_keep = ['text', 'source', 'school']
    if all(col in bible_df.columns for col in columns_to_keep):
        bible_df = bible_df[columns_to_keep]
        dfs_to_concat.append(bible_df)
        print(f"Bible data prepared: {len(bible_df)} verses")
    else:
        print(f"Bible missing required columns. Available: {bible_df.columns.tolist()}")

# Process Quran data if available
if quran_df is not None:
    # Add required columns
    if 'school' not in quran_df.columns:
        quran_df['school'] = 'islam'
    if 'source' not in quran_df.columns:
        quran_df['source'] = 'quran'

    # Rename EnglishTranslation to text
    if 'EnglishTranslation' in quran_df.columns:
        quran_df = quran_df.rename(columns={'EnglishTranslation': 'text'})

    # Select only the columns you need
    columns_to_keep = ['text', 'source', 'school']
    if all(col in quran_df.columns for col in columns_to_keep):
        quran_df = quran_df[columns_to_keep]
        dfs_to_concat.append(quran_df)
        print(f"Quran data prepared: {len(quran_df)} verses")
    else:
        print(f"Quran missing required columns. Available: {quran_df.columns.tolist()}")

# Concatenate all dataframes
combined_df = pd.concat(dfs_to_concat, ignore_index=True)

# Check if 'text' column exists before cleaning
if 'text' not in combined_df.columns:
    print(f"Error: 'text' column not found. Available columns: {combined_df.columns.tolist()}")
    # Try to find the text column with a different name
    if 'sentence_str' in combined_df.columns:
        combined_df = combined_df.rename(columns={'sentence_str': 'text'})
    else:
        print("Cannot proceed without a text column")
        raise ValueError("No text column found")

# Remove any empty or null texts
print(f"Before cleaning: {len(combined_df)} rows")
combined_df = combined_df.dropna(subset=['text'])
combined_df = combined_df[combined_df['text'].str.strip() != '']
print(f"After removing empty texts: {len(combined_df)} rows")

# Apply final capital cleaning to all texts together
philosophical_keywords = ['truth', 'wisdom', 'enlightenment', 'divine', 'sacred', 'spiritual',
                         'meditation', 'prayer', 'faith', 'compassion', 'love', 'peace', 'god']

# Extended helper function to return reason
def get_drop_reason(sentence, keywords, cap_threshold=0.3, min_len=8):
    if len(sentence.split()) < min_len:
        return "too_short"
    if capital_ratio(sentence, threshold=cap_threshold) and not contains_philosophical_terms(sentence, keywords):
        return "high_capital_no_keywords"
    return None  # means it's useful

try:
    # Add reason column (None means useful)
    combined_df['drop_reason'] = combined_df['text'].apply(
        lambda x: get_drop_reason(x, philosophical_keywords, cap_threshold=0.3, min_len=8)
    )
    if 'school' not in combined_df.columns:
        combined_df['school'] = combined_df['source'].apply(lambda x: 'islam' if x == 'quran' else 'christianity')
    # Separate dropped and useful
    dropped_df = combined_df[combined_df['drop_reason'].notnull()].copy()
    combined_df = combined_df[combined_df['drop_reason'].isnull()].drop(columns='drop_reason')

    # Save dropped with reasons
    dropped_df[['text', 'drop_reason', 'school']].to_csv("dropped_sentences.csv", index=False)
    print(f"Saved {len(dropped_df)} dropped sentences to 'dropped_sentences.csv'")

    # Print dropped sentences with reason
    print("Sentences dropped during advanced filtering:")
    for _, row in dropped_df.iterrows():
        print(f" - [{row['drop_reason']}] {row['text']}")

    print(f"After advanced filtering: {len(combined_df)} rows")

except NameError:
    print("sentence_is_useful function not available, skipping advanced filtering")


# Save the complete dataset
combined_df.to_csv('complete_religious_texts.csv', index=False)

# Download from Colab
files.download('complete_religious_texts.csv')

files.download('dropped_sentences.csv')
print(f"\nCombined dataset created with {len(combined_df)} sentences")
print(f"Schools included: {combined_df['school'].unique()}")
print(f"Sources included: {combined_df['source'].nunique()} different sources")
print(f"Breakdown by school:")
print(combined_df['school'].value_counts())
# Out:
# Streaming output truncated to the last 5000 lines.
#  - [high_capital_no_keywords] You are forever True, the Home of Excellence, the Primal Supreme Being.
#  - [high_capital_no_keywords] Waahay Guru, Waahay Guru, Waahay Guru, Waahay Jee.
#  - [high_capital_no_keywords] You are the Formless, Infinite Lord; who can compare to You?
#  - [high_capital_no_keywords] You are forever True, the Home of Excellence, the Primal Supreme Being.
#  - [high_capital_no_keywords] Waahay Guru, Waahay Guru, Waahay Guru, Waahay Jee.
#  - [too_short] No one can speak Your Unspoken Speech.
#  - [too_short] You are pervading the three worlds.
#  - [high_capital_no_keywords] You are forever True, the Home of Excellence, the Primal Supreme Being.
#  - [high_capital_no_keywords] Waahay Guru, Waahay Guru, Waahay Guru, Waahay Jee.
#  - [high_capital_no_keywords] || The True Guru, the True Guru, the True Guru is the Lord of the Universe Himself.
#  - [high_capital_no_keywords] He took birth in the Incarnations of the Fish, Tortoise and Wild Boar, and played His part.
#  - [high_capital_no_keywords] Enshrine this most excellent Name within your heart, and renounce the wickedness of the mind, Gayand the True Guru, the True Guru, the True Guru is the Lord of the Universe Himself.
#  - [high_capital_no_keywords] The Supreme Guru, the Supreme Guru, the Supreme Guru, the True, Dear Lord.
#  - [high_capital_no_keywords] the Supreme Guru, the Supreme Guru, the Supreme Guru, the True, Dear Lord.
#  - [too_short] Great is the Play of God!
#  - [too_short] Great is the Play of God!
#  - [too_short] Waahay Guru, this is all You, forever.
#  - [too_short] Brahmas and Shivas respect and obey You.
#  - [high_capital_no_keywords] Death of death, Formless Lord, I beg of You.
#  - [too_short] Waahay Guru, this is all Your making.
#  - [high_capital_no_keywords] The Lord is Inaccessible, Infinite, Eternal and Primordial; no one knows His beginning.
#  - [high_capital_no_keywords] Shiva and Brahma meditate on Him; the Vedas describe Him again and again.
#  - [high_capital_no_keywords] In this Dark Age of Kali Yuga, the Lord's Name is the Great Ship, to carry us all across the terrifying world ocean, safely to the other side.
#  - [high_capital_no_keywords] The Support of the Earth has established this Path of Dharma; He Himself remains lovingly attuned to the Lord, and does not wander in distraction.
#  - [high_capital_no_keywords] In the Hymns of the Vedas, Brahma sang His Praises; for His Sake, Shiva the silent sage held his place on the Kailaash Mountain.
#  - [high_capital_no_keywords] That True Guru, by the Pleasure of His Will, showered His Mercy upon all beings, and blessed Guru Raam Daas with the Glorious Greatness of the Naam.
#  - [high_capital_no_keywords] The Universe is intoxicated with the wine of Maya, but it has been saved; the All powerful Guru has blessed it with the Ambrosial Nectar of the Naam.
#  - [high_capital_no_keywords] His Gifts are vast and great; His awesome Power is supreme.
#  - [too_short] He Himself created Himself.
#  - [high_capital_no_keywords] The Eternal, Imperishable, Unmoving and Unchanging, Unborn, Self Existent, Primal Being of the Soul, the Infinity of the Infinite, the Eternal
#  - [high_capital_no_keywords] Great and Supreme Guru Raam Daas, Your Victory resounds across the universe.
#  - [high_capital_no_keywords] The Infinite Lord enshrined His Own Image in Guru Angad.
#  - [high_capital_no_keywords] Guru Amar Daas brought the Creator Lord under His control.
#  - [high_capital_no_keywords] Great and Supreme Guru Raam Daas, Your Victory resounds across the universe.
#  - [high_capital_no_keywords] || Naarad, Dhroo, Prahlaad and Sudaamaa are accounted among the Lord's devotees of the past.
#  - [high_capital_no_keywords] Ambreek, Jai Dayv, Trilochan, Naam Dayv and Kabeer are also remembered.
#  - [high_capital_no_keywords] Great and Supreme Guru Raam Daas, Your Victory resounds across the universe.
#  - [high_capital_no_keywords] Those who obtain the Blessed Vision of Your Darshan, by the karma of their good deeds, touch the Philosopher's Stone, and like the poet, sing Your Praises.
#  - [high_capital_no_keywords] Great and Supreme Guru Raam Daas, Your Victory resounds across the universe.
#  - [high_capital_no_keywords] So speaks the poet: Blessed is Guru Raam Daas; joining the Sangat, the Congregation, call Him blessed and great.
#  - [high_capital_no_keywords] Meditate on the True Guru, men, through Whom the Lord is obtained.
#  - [high_capital_no_keywords] Just as Guru Nanak was part and parcel, life and limb with Guru Angad, so is Guru Amar Daas one with Guru Raam Daas.
#  - [high_capital_no_keywords] Dhroo, Prahlaad, Kabeer and Trilochan chanted the Naam, the Name of the Lord, and His Illumination radiantly shines forth.
#  - [high_capital_no_keywords] Seeing Him, the mind is totally delighted; Guru Raam Daas is the Helper and Support of the Saints.
#  - [high_capital_no_keywords] || Guru Nanak realized the Immaculate Naam, the Name of the Lord.
#  - [high_capital_no_keywords] The Unspoken Speech of Guru Amar Daas cannot be expressed with only one tongue.
#  - [high_capital_no_keywords] I have heard that the most exalted Path of all is the Sangat, the Guru's Congregation.
#  - [too_short] Take me into Your Sanctuary!
#  - [high_capital_no_keywords] He brought the terrifying world ocean under His Control; by His Pleasure, He carried His Sikhs across.
#  - [high_capital_no_keywords] So speaks the poet: Guru Raam Daas, Your sovereign power is eternal and unbreakable; Your army is invincible.
#  - [high_capital_no_keywords] || You are the True Guru, throughout the four ages; You Yourself are the Transcendent Lord.
#  - [high_capital_no_keywords] You are Inaccessible; You are the Saving Grace of the Vedas.
#  - [too_short] You have conquered old age and death.
#  - [high_capital_no_keywords] So speaks the poet: Guru Raam Daas, You are the Destroyer of sins; I seek Your Sanctuary.
#  - [high_capital_no_keywords] I enshrine the Lotus Feet of the True Guru within my heart.
#  - [high_capital_no_keywords] The Word of the Guru's Shabad has been revealed, and the Lord dwells on His tongue.
#  - [high_capital_no_keywords] Attached to Guru Nanak, Guru Angad and Guru Amar Daas, He attained the supreme status.
#  - [high_capital_no_keywords] In the House of Guru Raam Daas, the devotee of the Lord, Guru Arjun was born.
#  - [high_capital_no_keywords] In the House of Guru Raam Daas, Guru Arjun has appeared as the Embodiment of the Fearless Lord.
#  - [high_capital_no_keywords] || The benign rule of Raja Janak has been established, and the Golden Age of Sat Yuga has begun.
#  - [high_capital_no_keywords] In the House of Guru Raam Daas, Guru Arjun has appeared as the Embodiment of the Infinite Lord.
#  - [high_capital_no_keywords] the poet utters the Praises of the Unborn, Self existent Lord.
#  - [high_capital_no_keywords] Guru Nanak blessed Guru Angad, and Guru Angad blessed Guru Amar Daas with the treasure.
#  - [high_capital_no_keywords] Guru Raam Daas blessed Guru Arjun, who touched the Philosopher's Stone, and was certified.
#  - [high_capital_no_keywords] || Guru Arjun, You are Eternal, Invaluable, Unborn, Self existent, the Destroyer of fear, the Dispeller of pain, Infinite and Fearless.
#  - [too_short] You bestow cooling and soothing peace.
#  - [high_capital_no_keywords] First, Guru Nanak, then Guru Angad and Guru Amar Daas, the True Guru, have been absorbed into the Word of the Shabad.
#  - [high_capital_no_keywords] Blessed, blessed is Guru Raam Daas, the Philosopher's Stone, who transformed Guru Arjun unto Himself.
#  - [high_capital_no_keywords] Kall Sahaar the poet utters Your Praise, Guru.
#  - [high_capital_no_keywords] Through the True Guru, You have realized the state of the Inaccessible, Unfathomable, Profound Lord.
#  - [high_capital_no_keywords] So speaks Guru Arjun, You have intuitively attained the state of Yoga within Yourself.
#  - [high_capital_no_keywords] Guru, the Word of Your Shabad eradicates egotism.
#  - [high_capital_no_keywords] || Sorat'h Guru Arjun is the certified Primal Person; like Arjuna, He never leaves the field of battle.
#  - [high_capital_no_keywords] The Naam, the Name of the Lord, is His spear and insignia.
#  - [high_capital_no_keywords] He is embellished with the Shabad, the Word of the True Guru.
#  - [high_capital_no_keywords] The Lord's Name is the Boat, the Bridge to cross over the terrifying world ocean.
#  - [high_capital_no_keywords] || The Naam is the Saving Grace of the world; by the Pleasure of the True Guru, it is obtained.
#  - [high_capital_no_keywords] || The Embodiment of Light, the Lord Himself is called Guru Nanak.
#  - [high_capital_no_keywords] From Him, came Guru Angad; His essence was absorbed into the essence.
#  - [high_capital_no_keywords] Guru Angad showed His Mercy, and established Amar Daas as the True Guru.
#  - [high_capital_no_keywords] Guru Amar Daas blessed Guru Raam Daas with the umbrella of immortality.
#  - [high_capital_no_keywords] So speaks Mat'huraa: gazing upon the Blessed Vision, the Darshan of Guru Raam Daas, His speech became as sweet as nectar.
#  - [high_capital_no_keywords] With your eyes, see the certified Primal Person, Guru Arjun, the Fifth Manifestation of the Guru.
#  - [high_capital_no_keywords] Meeting the Guru, touching the Philosopher's Stone, He was acclaimed as Guru.
#  - [high_capital_no_keywords] In this Dark Age of Kali Yuga, Guru Arjun is the Boat; attached to him, the entire universe is safely carried across.
#  - [high_capital_no_keywords] Devoted to His Worship, he remains attached to the Lord's Feet.
#  - [high_capital_no_keywords] Guru Raam Daas, to save the world, enshrined the Guru's Light into Guru Arjun.
#  - [high_capital_no_keywords] || In the great darkness of this world, the Lord revealed Himself, incarnated as Guru Arjun.
#  - [high_capital_no_keywords] || In the ocean of this Dark Age of Kali Yuga, the Lord's Name has been revealed in the Form of Guru Arjun, to save the world.
#  - [high_capital_no_keywords] He is the Pure, Immaculate Form of the Infinite Lord; except for Him, there is no other at all.
#  - [high_capital_no_keywords] The Sikhs of the Sangat all bathe in it.
#  - [high_capital_no_keywords] The Transcendent Lord Himself has placed the royal canopy over the head of Guru Arjun.
#  - [high_capital_no_keywords] Guru Nanak, Guru Angad, Guru Amar Daas and Guru Raam Daas met together before the Lord.
#  - [high_capital_no_keywords] The Lord offered Him His Royal Throne, and seated the Guru upon it.
#  - [high_capital_no_keywords] He gave the Royal Canopy and Throne to Guru Arjun, and came home.
#  - [too_short] One Universal Creator God.
#  - [too_short] Creative Being Personified.
#  - [too_short] Image Of The Undying.
#  - [high_capital_no_keywords] By Guru's Grace: Shaloks In Addition To The Vaars.
#  - [too_short] mother in law, how can I bow?
#  - [too_short] There is no guide or friend.
#  - [too_short] || They cry and weep and wail.
#  - [too_short] Nanak, I am a sacrifice to them.
#  - [high_capital_no_keywords] So proclaim the victory of the Society of the Saints, and act as Gurmukh.
#  - [too_short] Those people are wise and good looking.
#  - [too_short] Breaking his bonds, he is liberated.
#  - [high_capital_no_keywords] Such a Kh'shaatriyaa is accepted in the Court of the Lord.
#  - [too_short] See your Husband Lord within yourself.
#  - [too_short] False is its foundation.
#  - [too_short] There is no joy in this.
#  - [high_capital_no_keywords] || In his mind, Raam Chand mourned for Sita and Lachhman.
#  - [too_short] His stores of food never run out.
#  - [too_short] Nanak, my body is battered.
#  - [too_short] Nanak, unto whom should we complain?
#  - [too_short] Shalok, Third Mehl: One Universal Creator God.
#  - [high_capital_no_keywords] The Lord Himself misleads the misguided ones, and He Himself unites them in His Union.
#  - [high_capital_no_keywords] || I praise the Praiseworthy Lord, and sing the Praises of the True Lord.
#  - [high_capital_no_keywords] || Nanak, wherever I go, I find the True Lord.
#  - [high_capital_no_keywords] Wherever I look, I see the One Lord.
#  - [too_short] He reveals Himself to the Gurmukh.
#  - [high_capital_no_keywords] Those who meet with the True Guru are saved, through the Shabad, the True Word of the Inscrutable Lord.
#  - [high_capital_no_keywords] Whoever walks in harmony with the Will of the True Guru, and sings the Glorious Praises of the Lord, is pleasing to Him.
#  - [high_capital_no_keywords] Blessed, blessed are they, in this Dark Age of Kali Yuga, Nanak, who walk in harmony with the Will of the True Guru.
#  - [high_capital_no_keywords] || The Gurmukhs earn the wealth of the Lord, contemplating the Word of the Guru's Shabad.
#  - [high_capital_no_keywords] Through the Word of the Guru's Bani, they utter the Glorious Praises of the Lord, whose end and limitations cannot be found.
#  - [high_capital_no_keywords] Nanak, the Creator is the Doer of all; the Creator Lord beholds all.
#  - [too_short] Some are born, and some pass away.
#  - [high_capital_no_keywords] They come and go according to the Hukam of the Lord's Command.
#  - [high_capital_no_keywords] Those, upon whom the Lord showers His Mercy, come and meet the True Guru.
#  - [too_short] They always blossom in His love.
#  - [too_short] I am forever a sacrifice to them.
#  - [high_capital_no_keywords] Servant Nanak is the slave of those Gurmukhs who serve the Lord.
#  - [high_capital_no_keywords] || The True Guru, the Primal Being, has no hatred or vengeance.
#  - [high_capital_no_keywords] They do not remember the Name of the Lord, Har, Har; the Creator Himself brings them to ruin.
#  - [high_capital_no_keywords] The Lord showers His Mercy upon the Gurmukhs, and reunites the separated ones with Himself.
#  - [high_capital_no_keywords] Servant Nanak is a sacrifice to those who fall at the Feet of the True Guru.
#  - [high_capital_no_keywords] Those who are attached to the Naam, the Name of the Lord, are saved; without the Name, they must go to the City of Death.
#  - [high_capital_no_keywords] Nanak, they merge intuitively into the Lord, the Embodiment of Supreme Bliss.
#  - [high_capital_no_keywords] Through the Word of the Shabad, the Gurmukhs gain recognition in that Court of the True Lord.
#  - [high_capital_no_keywords] The Messenger of Death does not even approach them; the Creator Lord Himself forgives them.
#  - [high_capital_no_keywords] The Lord's Name is the Support of the Lord's humble servants.
#  - [high_capital_no_keywords] Servant Nanak celebrates the victory of those who meditate on the Name of the Lord, Har, Har.
#  - [high_capital_no_keywords] Joining the Saadh Sangat, the Guru's Congregation, the diamonds and jewels are obtained.
#  - [too_short] Without the Shabad, no one is liberated.
#  - [too_short] Screaming, Mine, mine!
#  - [high_capital_no_keywords] || Without the True Guru, there is no giver who can bestow the Support of the Lord's Name.
#  - [high_capital_no_keywords] Nanak, the Gurmukh finds the Lord, when He showers His Mercy.
#  - [high_capital_no_keywords] Meeting with the True Guru, one's filth is washed off, meditating on the Lord, the Primal Being, the All knowing One.
#  - [too_short] Body and soul are all His.
#  - [too_short] The Sovereign Lord King cherishes all.
#  - [high_capital_no_keywords] Through the Word of the Guru's Shabad, he is recognized in the Court of the Lord.
#  - [too_short] Without the Shabad, everyone is dead.
#  - [high_capital_no_keywords] They see the One Lord in all, and realize the Lord, the Supreme Soul of all.
#  - [too_short] But those who become Gurmukh understand everything.
#  - [high_capital_no_keywords] Nanak, the Gurmukhs look beautiful in that Court of the True Lord.
#  - [high_capital_no_keywords] || The Lord built the Harimandir, the Temple of the Lord; the Lord dwells within it.
#  - [high_capital_no_keywords] || Meditate on the Name of the Lord, Har, Har, mortal being, and you shall be honored in the Court of the Lord.
#  - [high_capital_no_keywords] She surrenders her body, mind and soul, Siblings of Destiny, and lives according to the Hukam of His Command.
#  - [high_capital_no_keywords] There is no other wealth as great, Siblings of Destiny; such is the greatness of the True Name.
#  - [high_capital_no_keywords] I sing forever the Glorious Praises of the True Lord; I shall remain with the True One forever.
#  - [high_capital_no_keywords] How can I praise Him, Siblings of Destiny?
#  - [high_capital_no_keywords] I am a sacrifice to the Blessed Vision of His Darshan.
#  - [high_capital_no_keywords] Great is the Glorious Greatness of the True Guru, Siblings of Destiny; if one is blessed with good karma, He is found.
#  - [high_capital_no_keywords] Nanak: they alone submit to His Command, Siblings of Destiny, who are pre destined to live the Name.
#  - [high_capital_no_keywords] Nanak, their faces appear beautiful in the Court of the True Lord.
#  - [high_capital_no_keywords] The True Word of the Shabad abides in their minds; they are absorbed in the True Guru.
#  - [high_capital_no_keywords] They are given a place in the Court of the True Lord; they are absorbed in the True Lord.
#  - [high_capital_no_keywords] Nanak, without the True Guru, the True Lord is not found.
#  - [too_short] The rainbird cries, Pri o!
#  - [high_capital_no_keywords] || rainbird, chirp the True Name, and let yourself be attuned to the True Lord.
#  - [high_capital_no_keywords] || The Primal Lord and Master has sent out the True Hukam of His Command.
#  - [high_capital_no_keywords] The True Lord Himself forgives them, and showering them with His Mercy, He leads them to walk in His Will.
#  - [high_capital_no_keywords] brides, sing the Glorious Praises of the Lord, and be absorbed in the True Word of His Shabad.
#  - [high_capital_no_keywords] Chant the Name of the Transcendent Lord, who is All powerful to create and destroy.
#  - [too_short] with sweet and sublime sounds.
#  - [too_short] Consider this Truth.
#  - [high_capital_no_keywords] Without the True Guru, no one finds the Lord.
#  - [high_capital_no_keywords] But if the Lord casts His Glance of Grace, then He Himself embellishes us.
#  - [high_capital_no_keywords] || Nanak, the Hukam, the Command of your Lord and Master, is prevailing.
#  - [high_capital_no_keywords] || The Lord Himself instructs those who are misguided, when He casts His Glance of Grace.
#  - [too_short] Shalok, Fourth Mehl: One Universal Creator God.
#  - [high_capital_no_keywords] By The Grace Of The True Guru: Blessed and very fortunate are those happy soul brides who, as Gurmukh, meet their Sovereign Lord King.
#  - [high_capital_no_keywords] Blessed and Great is the True Guru, the Primal Being, who has realized the True Lord.
#  - [high_capital_no_keywords] Blessed and Great is the True Guru, the True Primal Being, who looks upon all alike.
#  - [high_capital_no_keywords] Blessed and Great is the Formless True Guru, who has no end or limitation.
#  - [high_capital_no_keywords] Nanak, Blessed and Great is the True Guru, through whom the Naam, the Name of the Lord, is received.
#  - [high_capital_no_keywords] The True Guru is my Friend; if I meet Him, I will offer this mind as a sacrifice to Him.
#  - [high_capital_no_keywords] Whoever is blessed with the Lord's Glance of Grace, walks in harmony with the Will of the True Guru.
#  - [high_capital_no_keywords] The Blessed Vision of the True Guru's Darshan is fruitful; through it, one obtains the fruits of his desires.
#  - [high_capital_no_keywords] When they see their Husband Lord, Nanak, they are rejuvenated.
#  - [high_capital_no_keywords] They never break, Nanak, if one sings the Glorious Praises of the Lord.
#  - [too_short] Whatever the Gurmukh does, is devotional worship.
#  - [too_short] Whoever becomes Gurmukh contemplates the Lord.
#  - [high_capital_no_keywords] Those who have the Naam within, contemplate the Word of the Guru's Bani.
#  - [high_capital_no_keywords] Their faces are always radiant in the Court of the True Lord.
#  - [too_short] Without the Lord's Name, all is pain.
#  - [too_short] Attachment to Maya is agonizingly painful.
#  - [high_capital_no_keywords] In His Will, she serves; in His Will, she worship and adores Him.
#  - [too_short] In His Will, she merges in absorption.
#  - [high_capital_no_keywords] Nanak, those upon whom the Lord showers His Mercy, are merged and immersed in His Will.
#  - [high_capital_no_keywords] The Guru, the True Guru, is within; all worship and adore Him.
#  - [high_capital_no_keywords] Everyone comes to see the Blessed Vision of His Darshan.
#  - [high_capital_no_keywords] So believe in the True Guru, the supreme sublime Contemplator.
#  - [high_capital_no_keywords] They sing His Praises, and chant His Praises; in His Glorious Praises, they sleep in absorption.
#  - [too_short] Everything happens as He wills.
#  - [high_capital_no_keywords] || The Ambrosial Nectar of the Naam, the Name of the Lord, is within the True Guru.
#  - [high_capital_no_keywords] Following the Guru's Teachings, one meditates on the Immaculate Naam, the Pure and Holy Naam.
#  - [high_capital_no_keywords] The Ambrosial Word of His Bani is the true essence.
#  - [high_capital_no_keywords] The True Guru meditates on the Lord, the Primal Being.
#  - [high_capital_no_keywords] Those who join the Sat Sangat, and serve the True Guru the Guru unites them in the Lord's Union.
#  - [high_capital_no_keywords] On the Boat of the Naam, the Name of the Lord, the Guru carries us across.
#  - [high_capital_no_keywords] The Sikhs of the Guru accept and obey the Lord's Will; the Perfect Guru carries them across.
#  - [too_short] I am a sinner please save me.
#  - [high_capital_no_keywords] The Messenger of Death is beaten and driven away; we are saved in the Court of the Lord.
#  - [high_capital_no_keywords] Blessed and celebrated are the Sikhs of the Guru; in His Pleasure, the Lord unites them in His Union.
#  - [high_capital_no_keywords] Singing the Kirtan of the Praises of the Lord's Name, the Lord's path is illuminated and shown to His Sikhs.
#  - [high_capital_no_keywords] Conquering my egotism, I remain lovingly attuned to the One Lord; the Naam, the Name of the Lord, dwells within me.
#  - [high_capital_no_keywords] I follow the Guru's Teachings, and so the Messenger of Death cannot even see me; I am immersed in the True Name.
#  - [high_capital_no_keywords] The Creator Himself is All pervading; as He pleases, He links us to His Name.
#  - [too_short] Servant Nanak lives, chanting the Name.
#  - [high_capital_no_keywords] Nanak, this disease is eradicated only by meeting with the True Guru, the Holy Friend.
#  - [high_capital_no_keywords] || Following the Guru's Teachings, chant the Name of the Lord, Har, Har.
#  - [high_capital_no_keywords] Servant Nanak is the slave of the Lord, the slave of the slaves of the Guru, the True Guru.
#  - [too_short] Shalok, Fifth Mehl: One Universal Creator God.
#  - [high_capital_no_keywords] By The Grace Of The True Guru: They alone are imbued with the Lord, who do not turn their faces away from Him they realize Him.
#  - [high_capital_no_keywords] Even rolling in the dust, I look beautiful, Nanak, if my Husband Lord is with me.
#  - [high_capital_no_keywords] Nanak, singing the Glorious Praises of the Lord's Name, one's reputation is immaculate in the Court of the Lord.
#  - [high_capital_no_keywords] The treasure of the Naam, the Name of the Lord, is within them.
#  - [too_short] They cherish His Glorious Virtues forever.
#  - [high_capital_no_keywords] He shall cast His Glance of Grace, and attach you to Himself.
#  - [high_capital_no_keywords] My Friend is the True Supreme King, the King over the heads of kings.
#  - [too_short] One Universal Creator God.
#  - [high_capital_no_keywords] By The Grace Of The True Guru: Shalok, Ninth Mehl: If you do not sing the Praises of the Lord, your life is rendered useless.
#  - [too_short] Says Nanak, you are insane!
#  - [too_short] Nanak, know this as true.
#  - [high_capital_no_keywords] || He is the Saving Grace of sinners, the Destroyer of fear, the Master of the masterless.
#  - [too_short] Says Nanak, you are insane!
#  - [too_short] There is no other at all.
#  - [high_capital_no_keywords] || In this Dark Age of Kali Yuga, the Name of the Lord is the Destroyer of fear, the Eradicator of evil mindedness.
#  - [high_capital_no_keywords] || Vibrate with your tongue the Glorious Praises of the Lord of the Universe; with your ears, hear the Lord's Name.
#  - [high_capital_no_keywords] Says Nanak, without meditating on the Lord, he is caught by the noose of Death.
#  - [high_capital_no_keywords] The mortal is entangled in Maya; he has forgotten the Name of the Lord of the Universe.
#  - [high_capital_no_keywords] Says Nanak, without meditating on the Lord, he is caught in the noose of Death.
#  - [too_short] I am engrossed in evil mindedness, Nanak.
#  - [too_short] God, please save me!
#  - [too_short] Says Nanak, this is your condition.
#  - [high_capital_no_keywords] Nanak: everything is in Your hands, Lord; You are my Helper and Support.
#  - [high_capital_no_keywords] Says Nanak, in this tragedy, the Lord alone is my Support.
#  - [high_capital_no_keywords] || The Naam remains; the Holy Saints remain; the Guru, the Lord of the Universe, remains.
#  - [high_capital_no_keywords] Meditating in remembrance on it, my troubles are taken away; I have received the Blessed Vision of Your Darshan.
#  - [high_capital_no_keywords] The Ambrosial Nectar of the Naam, the Name of our Lord and Master, has been placed upon it as well; it is the Support of all.
#  - [too_short] You have taken pity on me.
#  - [high_capital_no_keywords] You took pity on me, and blessed me with Your Mercy, and I have met the True Guru, my Friend.
#  - [too_short] One Universal Creator God.
#  - [high_capital_no_keywords] By The Grace Of The True Guru: Raag Maalaa: Each Raga has five wives, and eight sons, who emit distinctive notes.
#  - [too_short] In the first place is Raag Bhairao.
#  - [high_capital_no_keywords] It is accompanied by the voices of its five Raaginis: First come Bhairavee, and Bilaavalee; then the songs of Punni aakee and Bangalee; and then Asalaykhee.
#  - [too_short] These are the five consorts of Bhairao.
#  - [high_capital_no_keywords] The sounds of Pancham, Harakh and Disaakh; the songs of Bangaalam, Madh and Maadhav.
#  - [high_capital_no_keywords] || In the second family is Maalakausak, who brings his five Raaginis: Gondakaree and Dayv Gandhaaree, the voices of Gandhaaree and Seehutee, and the fifth song of Dhanaasaree.
#  - [high_capital_no_keywords] This chain of Maalakausak brings along Maaroo, Masta ang and Mayvaaraa, Prabal, Chandakausak, Khau, Khat and Bauraanad singing.
#  - [too_short] These are the eight sons of Maalakausak.
#  - [high_capital_no_keywords] || There come Taylangee and Darvakaree; Basantee and Sandoor follow
#  - [too_short] ; then Aheeree, the finest of women.
#  - [too_short] These five wives come together.
#  - [high_capital_no_keywords] The sons: Surmaanand and Bhaaskar come, Chandrabinb and Mangalan follow.
#  - [too_short] Then comes the turn of Deepak.
#  - [high_capital_no_keywords] || Kachhaylee, Patamanjaree and Todee are sung; Kaamodee and Goojaree accompany Deepak.
#  - [high_capital_no_keywords] Kaalankaa, Kuntal and Raamaa, Kamalakusam and Champak are their names; Gauraa, Kaanaraa and Kaylaanaa; these are the eight sons of Deepak.
#  - [high_capital_no_keywords] Bairaaree and Karnaatee, the songs of Gawree and Aasaavaree; then follows Sindhavee.
#  - [high_capital_no_keywords] || Saaloo, Saarang, Saagaraa, Gond and Gambheer the eight sons of Siree Raag include Gund, Kumb and Hameer.
#  - [too_short] And finally comes the high tone Soohau.
#  - [too_short] These are the five with Maygh Raag.
#  - [too_short] Bairaadhar, Gajadhar, Kaydaaraa, Jabaleedhar, Nat and Jaladhaaraa.
#  - [too_short] I praise thee with reverence, Holy Gathas.
#  - [high_capital_no_keywords] Would I be able to approach the Wise and Mighty Lord of Life by obeying Sraosha, the voice of Conscience.
#  - [high_capital_no_keywords] Unto you, Creator, the Soul of Mother Earth complained thus:
#  - [too_short] Wherefore did you create me?
#  - [too_short] Who gave life to me?
#  - [too_short] Thus made Asha reply to Ahura Mazda!
#  - [too_short] He is the holy the Zarathushtra Spitama.
#  - [too_short] Thereupon, the Soul of Mother Earth bewailed.
#  - [high_capital_no_keywords] The Soul of Mother Earth continues: when shall ye all, Asha, Vohuman and Khashathra bring your welcome steps to us?
#  - [too_short] This situation shall continue for eternity.
#  - [high_capital_no_keywords] (In other words to follow the True Path and the Real Shepherd, or the False One who was not a true leader).
#  - [too_short] Let not the ignorant go astray.
#  - [high_capital_no_keywords] Among those sinners, Yima (Jamshid), the Son of Vivanghan is known to fame.
#  - [high_capital_no_keywords] Please grant them to us out of Thy Grace and Kindness.
#  - [high_capital_no_keywords] Unfold Thyself to me, Ahura, the Lord of Life, and grant me strength of soul and self sacrifice.
#  - [high_capital_no_keywords] May we approach Thee, Ahura Mazda, praising Thee and singing Thy songs.
#  - [high_capital_no_keywords] No other individual, except Thee, do I recognize, my Lord.
#  - [high_capital_no_keywords] What is Thy rule for progress and what is Thy Will?
#  - [too_short] How should we praise and worship Thee?
#  - [too_short] How should we worship Thee?
#  - [too_short] Who is the Creator inspiring Vohuman, Mazda?
#  - [too_short] Does Khashathra increase through pure mind?
#  - [high_capital_no_keywords] Kavis, Karapans and Usikhsh are opponents and enemies of Zoroaster.
#  - [too_short] y and continuity of soul.
#  - [too_short] To what land shall I turn?
#  - [too_short] Wither shall I turn for protection?
#  - [high_capital_no_keywords] Him shall we regard, my Lord, close knit with Asha and in tune with Ahura's Law.
#  - [high_capital_no_keywords] Besides through good deeds, you shall reach Asha as specified by Ahura's Eternal Law.
#  - [high_capital_no_keywords] Worship Ahura Mazda, who discerns the wise from the unwise and is Guardian of This World.
#  - [high_capital_no_keywords] Who so fulfills Zoroaster's best wish, he shall enjoy an Eternal Life as reward.
#  - [too_short] Great grandfather of Zoroaster.
#  - [too_short] This is Hobub in Pahlavi.
#  - [high_capital_no_keywords] The righteous shall enjoy, Ahura Mazda, the best gifts promised by Thee, through Thy Holy Spirit.
#  - [too_short] She, Armaiti, is indeed our safe refuge.
#  - [too_short] Let nothing tempt you to violence.
#  - [too_short] Hold on to love and good mind.
#  - [high_capital_no_keywords] With the above mentioned qualifications, he shall ultimately dwell, Ahura, in Thy Eternal Realm.
#  - [high_capital_no_keywords] What help shall come to Thy worshippers, Lord, through Asha.
#  - [high_capital_no_keywords] Does Zarathushtra enjoy Thy help as well through Vohuman?
#  - [high_capital_no_keywords] I praise Thee, Mazda Ahura, in my hymns and expect enjoying what Thou deemest the best.
#  - [too_short] Please refer to of Hat.
#  - [high_capital_no_keywords] Ahura, by chanting praises, I would worship Thee together with Asha, Vohuman and Khashathra as well.
#  - [too_short] Mazda, paradise is gained by good deeds.
#  - [high_capital_no_keywords] Of those persons to whom Thou hast been the First Teacher, inspiring them, Mazda.
#  - [too_short] Where doth Thy all embracing Love reside?
#  - [too_short] Where shall we find Asha, the Truth.
#  - [high_capital_no_keywords] Where dwelleth Thy most loving Vohuman, and where doth Thy strength of Sovereignty and Lordship, Mazda, doth emanate?
#  - [high_capital_no_keywords] Thou Creator of Our Mother Earth, the Water and the Plants, Mazda, grant me Eternal Perfection, through Thy most Holy Spirit.
#  - [high_capital_no_keywords] The reward which Zoroaster has promised the Magians and all the followers of this religion is Garo Nemana or the House of Songs and Praise, the Paradise.
#  - [high_capital_no_keywords] This abode has been the House on High from Eternity, where Ahura Mazda dwells.
#  - [high_capital_no_keywords] Grant us, Ahura, those blessings that we may ever cling to Thee, Mazda.
#  - [high_capital_no_keywords] Through Vohuman and control of self, Ahura Mazda shall grant us His blessings.
#  - [high_capital_no_keywords] Its important members where Vishtaspa, Frashaoshtra, Jamaspa and Maidyo Mah.
#  - [too_short] They look down upon respectable persons.
#  - [too_short] He should be earnest and truthful.
#  - [too_short] 'Hold faithfulness and sincerity as first principles.
#  - [too_short] 'Have no friends not equal to yourself.
#  - [too_short] Does he ask his information?
#  - [too_short] or is it given to him?'.
#  - [too_short] 'At thirty, I stood firm.
#  - [too_short] 'At forty, I had no doubts.
#  - [too_short] I asked what filial piety was.
#  - [too_short] Fan Ch'ih said, 'What did you mean?'
#  - [too_short] Mang Wu asked what filial piety was.
#  - [too_short] Tsze yu asked what filial piety was.
#  - [too_short] Tsze hsia asked what filial piety was.
#  - [too_short] 'Examine in what things he rests.
#  - [too_short] 'How can a man conceal his character?.
#  - [too_short] How can a man conceal his character?'
#  - [too_short] These qualities are displayed in government.
#  - [too_short] The Master said, 'A great question indeed!.
#  - [too_short] He answered, 'I cannot.'
#  - [too_short] Confucius said, 'Alas!
#  - [too_short] The pretty dimples of her artful smile!
#  - [too_short] The plain ground for the colours?.
#  - [too_short] 'Ceremonies then are a subsequent thing?'
#  - [too_short] The Master said, 'I do not know.
#  - [too_short] The Master said, 'Not so.
#  - [too_short] How complete and elegant are its regulations!
#  - [too_short] This was the old way.'.
#  - [high_capital_no_keywords] The Master said, 'Small indeed was the capacity of Kwan Chung!'.
#  - [too_short] Kwan had also such a stand.
#  - [too_short] Poverty and meanness are what men dislike.
#  - [too_short] The disciple Tsang replied, 'Yes.'.
#  - [too_short] The Master said, 'The cautious seldom err.'
#  - [too_short] He who practises it will have neighbors.'
#  - [too_short] The Master said, 'You are a utensil.'
#  - [too_short] 'What utensil?' 'A gemmed sacrificial utensil.'.
#  - [too_short] The Master was pleased.
#  - [too_short] The Master said, 'I do not know.'.
#  - [too_short] 'And what do you say of Ch'iu?'
#  - [too_short] 'What do you say of Ch'ih?'
#  - [high_capital_no_keywords] The Master said to Tsze kung, 'Which do you consider superior, yourself or Hui?'.
#  - [too_short] Of what sort was his wisdom?'.
#  - [too_short] 'Was he perfectly virtuous?'
#  - [too_short] How can he be pronounced perfectly virtuous?'.
#  - [too_short] The Master replied, 'He was pure.'
#  - [too_short] 'Was he perfectly virtuous?'
#  - [too_short] How can he be pronounced perfectly virtuous?'
#  - [too_short] Chi Wan thought thrice, and then acted.
#  - [high_capital_no_keywords] The Master said, 'Who says of Wei shang Kao that he is upright?
#  - [too_short] I also am ashamed of them.
#  - [too_short] I also am ashamed of it.'.
#  - [too_short] The Master said, 'It is all over!
#  - [too_short] The Master said, 'There is Yung!
#  - [too_short] The Master said, 'He may pass.
#  - [too_short] He does not mind small matters.'.
#  - [too_short] The Master said, 'Yung's words are right.'
#  - [too_short] The Master said, 'Give her a fu.'
#  - [too_short] 'Give her an yu,' said the Master.
#  - [too_short] Yen gave her five ping.
#  - [too_short] The Master said, 'Do not decline them.
#  - [high_capital_no_keywords] The chief of the Chi family sent to ask Min Tsze ch'ien to be governor of Pi.
#  - [too_short] It is the appointment of Heaven, alas!
#  - [too_short] Admirable indeed was the virtue of Hui!'
#  - [too_short] My horse would not advance.
#  - [too_short] Fan Ch'ih asked what constituted wisdom.
#  - [too_short] He asked about perfect virtue.
#  - [too_short] A strange cornered vessel!
#  - [too_short] A strange cornered vessel!'
#  - [too_short] Confucius said, 'Why should he do so?'
#  - [high_capital_no_keywords] The Master said, 'Perfect is the virtue which is according to the Constant Mean!
#  - [too_short] Might he be called perfectly virtuous?'
#  - [too_short] The Master said, 'Extreme is my decay.
#  - [too_short] 'Let perfect virtue be accorded with.
#  - [too_short] They were ancient worthies,' said the Master.
#  - [high_capital_no_keywords] The Master's frequent themes of discourse were the Odes, the History, and the maintenance of the Rules of Propriety.
#  - [too_short] On all these he frequently discoursed.
#  - [high_capital_no_keywords] The Duke of Sheh asked Tsze lu about Confucius, and Tsze lu did not answer him.
#  - [too_short] I conceal nothing from you.
#  - [too_short] He shot, but not at birds perching.
#  - [too_short] Why must one be so severe?
#  - [too_short] Tsze lu replied, 'It may.
#  - [too_short] He is a superior man indeed.'.
#  - [too_short] How majestic was he!
#  - [too_short] How vast was his virtue!
#  - [too_short] Only when the dynasties of T
#  - [too_short] I will practise charioteering.'.
#  - [too_short] How various is his ability!'.
#  - [too_short] And, moreover, his ability is various.'.
#  - [too_short] He does not need variety of ability.'.
#  - [too_short] Should I impose upon Heaven?.
#  - [too_short] The Master said, 'Sell it!
#  - [too_short] Some one said, 'They are rude.
#  - [too_short] How can you do such a thing?'
#  - [too_short] The Master said of Yen Yuan, 'Alas!
#  - [too_short] I saw his constant advance.
#  - [too_short] Have no friends not equal to yourself.
#  - [too_short] Do I not think of you?
#  - [too_short] But your house is distant.
#  - [too_short] How is it distant?'.
#  - [too_short] He did not eat much.
#  - [too_short] When eating, he did not converse.
#  - [too_short] When in bed, he did not speak.
#  - [too_short] I dare not taste it.'
#  - [too_short] He did not ask about the horses.
#  - [too_short] He first tasted everything.
#  - [too_short] Seeing the countenance, it instantly rises.
#  - [too_short] Tsze lu made a motion to it.
#  - [too_short] Thrice it smelt him and then rose.
#  - [high_capital_no_keywords] The Master said, 'Filial indeed is Min Tsze ch'ien!
#  - [high_capital_no_keywords] When Yen Yuan died, the Master said, 'Alas!
#  - [too_short] Heaven is destroying me!
#  - [too_short] Heaven is destroying me!'.
#  - [too_short] 'Is it excessive?' said he.
#  - [too_short] The Master was pleased.
#  - [too_short] He said, 'Yu, there!
#  - [too_short] he will not die a natural death.'.
#  - [too_short] The Master said, 'There is Hui!
#  - [too_short] He has nearly attained to perfect virtue.
#  - [too_short] He is often in want.
#  - [too_short] Yet his judgments are often correct.'
#  - [too_short] or is his gravity only in appearance?'
#  - [high_capital_no_keywords] The Master was put in fear in K'wang and Yen Yuan fell behind.
#  - [high_capital_no_keywords] Tsze lu, Tsang Hsi, Zan Yu, and Kung hsi Hwa were sitting by the Master.
#  - [too_short] The Master smiled at him.
#  - [high_capital_no_keywords] 'What are your wishes, Ch'ih,' said the Master next to Kung hsi Hwa.
#  - [too_short] Yen Yuan asked about perfect virtue.
#  - [too_short] Chung kung asked about perfect virtue.
#  - [too_short] Sze ma Niu asked about perfect virtue.
#  - [too_short] 'Cautious and slow in his speech!'
#  - [too_short] 'Being without anxiety or fear!'
#  - [too_short] Tsze chang asked what constituted intelligence.
#  - [too_short] Tsze kung asked about government.
#  - [too_short] The Master answered, 'Part with the food.
#  - [too_short] Tsze kung said, 'Alas!
#  - [too_short] This is a case of delusion.
#  - [high_capital_no_keywords] The Duke Ching, of Ch'i, asked Confucius about government.
#  - [too_short] The Master said, 'Ah!
#  - [too_short] Tsze lu never slept over a promise.
#  - [too_short] Tsze chang asked about government.
#  - [too_short] Chi K'ang asked Confucius about government.
#  - [too_short] Confucius replied, 'To govern means to rectify.
#  - [too_short] The Master said, 'Truly a good question!.
#  - [too_short] Fan Ch'ih asked about benevolence.
#  - [too_short] He asked about knowledge.
#  - [too_short] Tsze kung asked about friendship.
#  - [too_short] If you find him impracticable, stop.
#  - [too_short] Do not disgrace yourself.'
#  - [too_short] Tsze lu asked about government.
#  - [too_short] So, indeed!' said Tsze lu.
#  - [too_short] 'You are wide of the mark!
#  - [too_short] Why must there be such rectification?'.
#  - [too_short] Fan Ch'ih requested to be taught husbandry.
#  - [too_short] here is a collection!'
#  - [too_short] this is admirable!'.
#  - [high_capital_no_keywords] When the Master went to Wei, Zan Yu acted as driver of his carriage.
#  - [too_short] The Master said, 'Teach them.'
#  - [too_short] True indeed is this saying!'
#  - [too_short] He replied, 'We had government business.'
#  - [too_short] The Duke of Sheh asked about government.
#  - [too_short] Uprightness is to be found in this.'
#  - [too_short] Fan Ch'ih asked about perfect virtue.
#  - [too_short] They are obstinate little men.
#  - [too_short] The Master said 'Pooh!
#  - [too_short] Hsien asked what was shameful.
#  - [too_short] An esteemer of virtue indeed is this!'
#  - [too_short] Some one asked about Tsze ch'an.
#  - [too_short] He asked about Tsze hsi.
#  - [too_short] The Master said, 'That man!
#  - [too_short] He asked about Kwan Chung. '
#  - [too_short] Tsze lu asked what constituted a man.
#  - [too_short] The Master said, 'So!
#  - [too_short] But is it so with him?'
#  - [too_short] Whose beneficence was like his?
#  - [too_short] Whose beneficence was like his?'.
#  - [too_short] Moreover, he became prime minister to Hwan.'.
#  - [high_capital_no_keywords] Chan Ch'ang murdered the Duke Chien of Ch'i.
#  - [too_short] Confucius sat with him, and questioned him.
#  - [too_short] A messenger indeed!'
#  - [too_short] Now, I have not leisure for this.'
#  - [too_short] The Master said, 'Alas!
#  - [too_short] there is no one that knows me.'.
#  - [too_short] I do not grumble against men.
#  - [too_short] But there is Heaven; that knows me!'.
#  - [too_short] Some retire from particular states.
#  - [too_short] Some retire because of disrespectful looks.
#  - [too_short] Some retire because of contradictory language.'.
#  - [too_short] Tsze lu said, 'From Mr. K'ung.'
#  - [too_short] But this is not difficult!'.
#  - [too_short] The ancients all did so.
#  - [too_short] 'And is this all?' said Tsze lu.
#  - [too_short] again asked Tsze lu.
#  - [too_short] He wishes quickly to become a man.'.
#  - [high_capital_no_keywords] The Duke Ling of Wei asked Confucius about tactics.
#  - [high_capital_no_keywords] The Master said, 'Follow the seasons of Hsia. '
#  - [too_short] Ride in the state carriage of Yin.
#  - [too_short] 'Wear the ceremonial cap of Chau.
#  - [too_short] The Master said, 'It is all over!
#  - [too_short] What shall I think of this?
#  - [too_short] I can indeed do nothing with him!'
#  - [too_short] He brings it forth in humility.
#  - [too_short] He completes it with sincerity.
#  - [too_short] This is indeed a superior man.'
#  - [too_short] He is sociable, but not a partizan.'
#  - [too_short] there are no such things.'
#  - [too_short] The Master said, 'Specious words confound virtue.
#  - [too_short] The better plan is to learn.'
#  - [too_short] Food is not his object.
#  - [too_short] The Master said, 'Yes.
#  - [too_short] 'And further, you speak wrongly.
#  - [too_short] He stands in awe of great men.
#  - [too_short] He is disrespectful to great men.
#  - [too_short] 'Is not that saying illustrated by this?'.
#  - [too_short] I retired and studied the Odes. '
#  - [too_short] I have heard about the Odes.
#  - [too_short] She calls herself T'.
#  - [too_short] He met him, however, on the way.
#  - [too_short] Confucius replied, 'No.'
#  - [too_short] What I said was only in sport.'
#  - [too_short] Tsze chang asked Confucius about perfect virtue.
#  - [too_short] 'Am I a bitter gourd!
#  - [too_short] Yu replied, 'I have not.'.
#  - [too_short] 'The Odes serve to stimulate the mind.
#  - [too_short] 'They teach the art of sociability.
#  - [too_short] It is music, they say.
#  - [too_short] It is music, they say.
#  - [too_short] The Master said, 'Does Heaven speak?
#  - [too_short] 'I should,' replied Wo.
#  - [too_short] Are there not gamesters and chess players?
#  - [too_short] The Master said, 'He has his hatreds.
#  - [high_capital_no_keywords] The Viscount of Chi became a slave to Chau.
#  - [too_short] Pi kan remonstrated with him and died.
#  - [too_short] Confucius took his departure.
#  - [too_short] Confucius took his departure.
#  - [too_short] Give up your vain pursuit.
#  - [too_short] Give up your vain pursuit.
#  - [too_short] He answered, 'I am Chung Yu.'
#  - [too_short] 'I am different from all these.
#  - [high_capital_no_keywords] To Chau belonged the eight officers, Po ta, Po kwo, Chung tu, Chung hwu, Shu ya, Shu hsia, Chi sui, and Chi kwa.
#  - [too_short] In sacrificing, his thoughts are reverential.
#  - [too_short] Such a man commands our approbation indeed.'
#  - [too_short] Am I devoid of talents and virtue?
#  - [too_short] men will put me away from them.
#  - [too_short] They are to be found among men.
#  - [too_short] My wall only reaches to the shoulders.
#  - [too_short] Chung ni cannot be reviled.
#  - [too_short] While he lived, he would be glorious.
#  - [too_short] Sincerely hold fast the due Mean.
#  - [too_short] By his generosity, he won all.
#  - [too_short] By his justice, all were delighted.
#  - [too_short] Together we call them the Mystery.
#  - [high_capital_no_keywords] This is called the Form of the Formless, and the Semblance of the Invisible; this is called the Fleeting and Indeterminable.
#  - [too_short] Who can (make) the muddy water (clear)?
#  - [too_short] Who can secure the condition of rest?
#  - [too_short] Those three methods (of government)
#  - [too_short] and many lusts eschew.
#  - [too_short] I alone seem to have lost everything.
#  - [too_short] Who can of Tao the nature tell?
#  - [too_short] Profound it is, dark and obscure;
#  - [too_short] Things' essences all there endure.
#  - [too_short] By this (nature of the Tao).
#  - [too_short] To Heaven and Earth.
#  - [too_short] Great, it passes on (in constant flow).
#  - [too_short] Passing on, it becomes remote.
#  - [too_short] Having become remote, it returns.
#  - [too_short] All pervading is the Great Tao!
#  - [high_capital_no_keywords] The Tao produced One; One produced Two; Two produced Three; Three produced All things.
#  - [too_short] Who is content Needs fear no shame.
#  - [too_short] Who knows to stop Incurs no blame.
#  - [too_short] From danger free Long live shall he.
#  - [too_short] And for what reason?
#  - [too_short] And for what reason?
#  - [too_short] This is contrary to the Tao surely!.
#  - [too_short] By this (method of observation).
#  - [too_short] This is called 'the Mysterious Agreement.'.
#  - [too_short] misery lurks beneath it!
#  - [too_short] Shall we then dispense with correction?
#  - [too_short] To know and yet (thi
#  - [too_short] The sage has not the disease.
#  - [too_short] (So it is with) all things.
#  - [too_short] They all the name of King accord.'.
#  - [too_short] The sage does not accumulate (for himself).
#  - [high_capital_no_keywords] And here we shall set forth the revelation, the declaration, and the narration of all that was hidden, the revelation by Tzacol, Bitol, Alom, Qaholom, who are called Hunahp Vuch, Hunahp Uti Zaqui Nim Tzi, Tepeu, Gucumatz, Qux cho, Qux Pal Ali Rax Lac, Ah Rax Tzel, as they were called.
#  - [too_short] The first is called Caculh Hurac.
#  - [too_short] The second is Chipi Caculh.
#  - [too_short] The third is Raxa Caculh.
#  - [too_short] Thus let it be done!
#  - [too_short] Let the emptiness be filled!
#  - [too_short] Then the earth was created by them.
#  - [too_short] they said, and instantly it was made.
#  - [too_short] Chipi Caculh Raxa Caculh
#  - [too_short] vipers, guardians of the thickets.
#  - [too_short] So it was they spoke.
#  - [high_capital_no_keywords] Invoke then, Hurac, ChipiCaculh Raxa Caculh the Heart of Heaven, the Heart of Earth, the Creator, the Maker, the Forefathers; speak, invoke us, adore us, they were told.
#  - [too_short] This shall be your lot.
#  - [too_short] Then was the creation and the formation.
#  - [too_short] Let us consider this, they said.
# ...
#  - [too_short] But We see it (quite) near.
#  - [too_short] And the mountains will be like wool,
#  - [too_short] His wife and his brother,
#  - [too_short] His kindred who sheltered him,
#  - [high_capital_no_keywords] By no means! for it would be the Fire of Hell!-
#  - [too_short] Truly man was created very impatient;-
#  - [too_short] Fretful when evil touches him;
#  - [too_short] And niggardly when good reaches him;-
#  - [too_short] Not so those devoted to Prayer;-
#  - [too_short] Those who remain steadfast to their prayer;
#  - [too_short] And those who guard their chastity,
#  - [too_short] "So I have called to them aloud;
#  - [too_short] "And they have devised a tremendous Plot.
#  - [high_capital_no_keywords] And Noah, said: "O my Lord! Leave not of the Unbelievers, a single one on earth!
#  - [too_short] O thou folded in garments!
#  - [too_short] Half of it,- or a little less,
#  - [high_capital_no_keywords] And a Food that chokes, and a Penalty Grievous.
#  - [too_short] O thou wrapped up (in the mantle)!
#  - [too_short] Arise and deliver thy warning!
#  - [too_short] And thy Lord do thou magnify!
#  - [too_short] And thy garments keep free from stain!
#  - [too_short] And all abomination shun!
#  - [too_short] Finally, when the Trumpet is sounded,
#  - [high_capital_no_keywords] That will be- that Day - a Day of Distress,-
#  - [too_short] Far from easy for those without Faith.
#  - [too_short] To whom I granted resources in abundance,
#  - [too_short] And sons to be by his side!-
#  - [high_capital_no_keywords] By no means! For to Our Signs he has been refractory!
#  - [too_short] For he thought and he plotted;-
#  - [too_short] And woe to him! How he plotted!-
#  - [too_short] Yea, Woe to him; How he plotted!-
#  - [too_short] Then he looked round;
#  - [too_short] Then he frowned and he scowled;
#  - [too_short] Then he turned back and was haughty;
#  - [too_short] Soon will I cast him into Hell-Fire!
#  - [too_short] Darkening and changing the colour of man!
#  - [too_short] Over it are Nineteen.
#  - [too_short] Nay, verily: By the Moon,
#  - [too_short] And by the Night as it retreateth,
#  - [too_short] A warning to mankind,-
#  - [too_short] Except the Companions of the Right Hand.
#  - [too_short] And (ask) of the Sinners:
#  - [too_short] "What led you into Hell Fire?"
#  - [high_capital_no_keywords] "And we used to deny the Day of Judgment,
#  - [too_short] As if they were affrighted asses,
#  - [too_short] Fleeing from a lion!
#  - [too_short] Nay, this surely is an admonition:
#  - [high_capital_no_keywords] But none will keep it in remembrance except as Allah wills: He is the Lord of Righteousness, and the Lord of Forgiveness.
#  - [high_capital_no_keywords] I do call to witness the Resurrection Day;
#  - [high_capital_no_keywords] He questions: "When is the Day of Resurrection?"
#  - [too_short] At length, when the sight is dazed,
#  - [too_short] And the moon is buried in darkness.
#  - [high_capital_no_keywords] That Day will Man say: "Where is the refuge?"
#  - [too_short] By no means! No place of safety!
#  - [too_short] Nay, man will be evidence against himself,
#  - [too_short] And leave alone the Hereafter.
#  - [too_short] Looking towards their Lord;
#  - [high_capital_no_keywords] That Day the Drive will be (all) to thy Lord!
#  - [too_short] Woe to thee, (O men!), yea, woe!
#  - [high_capital_no_keywords] As to the Righteous, they shall drink of a Cup (of Wine) mixed with Kafur,-
#  - [high_capital_no_keywords] "We only fear a Day of distressful Wrath from the side of our Lord."
#  - [too_short] A fountain there, called Salsabil.
#  - [too_short] Which then blow violently in tempestuous Gusts,
#  - [too_short] And scatter (things) far and wide;
#  - [too_short] Then separate them, one from another,
#  - [too_short] Then spread abroad a Message,
#  - [too_short] Whether of Justification or of Warning;-
#  - [too_short] Then when the stars become dim;
#  - [too_short] When the heaven is cleft asunder;
#  - [too_short] For what Day are these (portents) deferred?
#  - [too_short] For the Day of Sorting out.
#  - [too_short] The living and the dead,
#  - [high_capital_no_keywords] Thus do We certainly reward the Doers of Good.
#  - [too_short] Concerning what are they disputing?
#  - [too_short] Concerning the Great News,
#  - [too_short] About which they cannot agree.
#  - [too_short] Verily, they shall soon (come to) know!
#  - [too_short] And the mountains as pegs?
#  - [too_short] And made your sleep for rest,
#  - [too_short] And made the night as a covering,
#  - [too_short] And placed (therein) a Light of Splendour?
#  - [too_short] And gardens of luxurious growth?
#  - [too_short] For the transgressors a place of destination:
#  - [too_short] They will dwell therein for ages.
#  - [too_short] A fitting recompense (for them).
#  - [too_short] Gardens enclosed, and grapevines;
#  - [too_short] And voluptuous women of equal age;
#  - [too_short] And a cup full (to the brim).
#  - [too_short] Then press forward as in a race,
#  - [high_capital_no_keywords] Then arrange to do (the Commands of their Lord),
#  - [too_short] Followed by oft-repeated (commotions):
#  - [too_short] Hearts that Day will be in agitation;
#  - [too_short] Cast down will be (their owners') eyes.
#  - [too_short] Has the story of Moses reached thee?
#  - [high_capital_no_keywords] Then did (Moses) show him the Great Sign.
#  - [too_short] But (Pharaoh) rejected it and disobeyed (guidance);
#  - [too_short] Saying, "I am your Lord, Most High".
#  - [too_short] And the mountains hath He firmly fixed;-
#  - [too_short] The Abode will be Hell-Fire;
#  - [too_short] Their abode will be the Garden.
#  - [too_short] (The Prophet) frowned and turned away,
#  - [too_short] To him dost thou attend;
#  - [too_short] And with fear (in his heart),
#  - [too_short] Of him wast thou unmindful.
#  - [high_capital_no_keywords] By no means (should it be so)! For it is indeed a Message of instruction:
#  - [too_short] Exalted (in dignity), kept pure and holy,
#  - [too_short] (Written) by the hands of scribes-
#  - [too_short] Honourable and Pious and Just.
#  - [too_short] From what stuff hath He created him?
#  - [too_short] And We split the earth in fragments,
#  - [too_short] And produce therein corn,
#  - [too_short] And Grapes and nutritious plants,
#  - [too_short] And Olives and Dates,
#  - [too_short] And enclosed Gardens, dense with lofty trees,
#  - [too_short] And fruits and fodder,-
#  - [too_short] And from his mother and his father,
#  - [too_short] And from his wife and his children.
#  - [too_short] Some faces that Day will be beaming,
#  - [too_short] Laughing, rejoicing.
#  - [too_short] Blackness will cover them:
#  - [too_short] When the stars fall, losing their lustre;
#  - [too_short] When the mountains vanish (like a mirage);
#  - [too_short] For what crime she was killed;
#  - [too_short] When the scrolls are laid open;
#  - [too_short] When the world on High is unveiled;
#  - [too_short] And when the Garden is brought near;-
#  - [too_short] Go straight, or hide;
#  - [too_short] And the Night as it dissipates;
#  - [high_capital_no_keywords] Endued with Power, with rank before the Lord of the Throne,
#  - [too_short] When whither go ye?
#  - [too_short] When the Sky is cleft asunder;
#  - [too_short] When the Stars are scattered;
#  - [high_capital_no_keywords] O man! What has seduced thee from thy Lord Most Beneficent?-
#  - [high_capital_no_keywords] Nay! But ye do reject Right and Judgment!
#  - [too_short] Kind and honourable,- Writing down (your deeds):
#  - [too_short] Woe to those that deal in fraud,-
#  - [too_short] On a Mighty Day,
#  - [too_short] (There is) a Register (fully) inscribed.
#  - [too_short] Woe, that Day, to those that deny-
#  - [too_short] Those that deny the Day of Judgment.
#  - [high_capital_no_keywords] When Our Signs are rehearsed to him, he says, "Tales of the ancients!"
#  - [too_short] (There is) a Register (fully) inscribed,
#  - [high_capital_no_keywords] To which bear witness those Nearest (to Allah).
#  - [too_short] Truly the Righteous will be in Bliss:
#  - [high_capital_no_keywords] But on this Day the Believers will laugh at the Unbelievers:
#  - [too_short] When the sky is rent asunder,
#  - [too_short] And when the earth is flattened out,
#  - [too_short] Soon will he cry for perdition,
#  - [too_short] And he will enter a Blazing Fire.
#  - [too_short] The Night and its Homing;
#  - [too_short] And the Moon in her fullness:
#  - [too_short] So announce to them a Penalty Grievous,
#  - [too_short] By the sky, (displaying) the Zodiacal Signs;
#  - [too_short] By the promised Day (of Judgment);
#  - [too_short] Fire supplied (abundantly) with fuel:
#  - [too_short] Behold! they sat over against the (fire),
#  - [high_capital_no_keywords] And they ill-treated them for no other reason than that they believed in Allah, Exalted in Power, Worthy of all Praise!-
#  - [high_capital_no_keywords] Truly strong is the Grip (and Power) of thy Lord.
#  - [high_capital_no_keywords] And He is the Oft-Forgiving, Full of Loving-Kindness,
#  - [too_short] Lord of the Throne of Glory,
#  - [too_short] Of Pharaoh and the Thamud?
#  - [too_short] But Allah doth encompass them from behind!
#  - [too_short] Nay, this is a Glorious Qur'an,
#  - [too_short] (Inscribed) in a Tablet Preserved!
#  - [too_short] By the Sky and the Night-Visitant (therein);-
#  - [too_short] (It is) the Star of piercing brightness;-
#  - [too_short] He is created from a drop emitted-
#  - [high_capital_no_keywords] Behold this is the Word that distinguishes (Good from Evil):
#  - [too_short] It is not a thing for amusement.
#  - [too_short] And I am planning a scheme.
#  - [high_capital_no_keywords] Glorify the name of thy Guardian-Lord Most High,
#  - [too_short] Who hath ordained laws. And granted guidance;
#  - [too_short] Who will enter the Great Fire,
#  - [too_short] But those will prosper who purify themselves,
#  - [too_short] The Books of Abraham and Moses.
#  - [too_short] Some faces, that Day, will be humiliated,
#  - [too_short] Labouring (hard), weary,-
#  - [too_short] The while they enter the Blazing Fire,-
#  - [too_short] Which will neither nourish nor satisfy hunger.
#  - [too_short] (Other) faces that Day will be joyful,
#  - [too_short] Pleased with their striving,-
#  - [too_short] In a Garden on high,
#  - [too_short] Therein will be a bubbling spring:
#  - [too_short] Goblets placed (ready),
#  - [too_short] And cushions set in rows,
#  - [too_short] And rich carpets (all) spread out.
#  - [too_short] For to Us will be their return;
#  - [too_short] By the break of Day
#  - [too_short] By the Nights twice five;
#  - [too_short] By the even and odd (contrasted);
#  - [too_short] And with Pharaoh, lord of stakes?
#  - [too_short] And heaped therein mischief (on mischief).
#  - [high_capital_no_keywords] For thy Lord is (as a Guardian) on a watch-tower.
#  - [too_short] And ye love wealth with inordinate love!
#  - [too_short] "Enter thou, then, among My devotees!
#  - [too_short] "Yea, enter thou My Heaven!
#  - [too_short] I do call to witness this City;-
#  - [too_short] Thinketh he that none beholdeth him?
#  - [too_short] And shown him the two highways?
#  - [too_short] (It is:) freeing the bondman;
#  - [too_short] To the orphan with claims of relationship,
#  - [high_capital_no_keywords] Such are the Companions of the Right Hand.
#  - [high_capital_no_keywords] But those who reject Our Signs, they are the (unhappy) Companions of the Left Hand.
#  - [too_short] By the Sun and his (glorious) splendour;
#  - [too_short] By the Moon as she follows him;
#  - [high_capital_no_keywords] By the Day as it shows up (the Sun's) glory;
#  - [too_short] By the Night as it conceals it;
#  - [too_short] By the Firmament and its (wonderful) structure;
#  - [too_short] By the Earth and its (wide) expanse:
#  - [too_short] Truly he succeeds that purifies it,
#  - [too_short] And he fails that corrupts it!
#  - [too_short] And gives the lie to the best,-
#  - [too_short] Verily We take upon Ourselves to guide,
#  - [high_capital_no_keywords] But only the desire to seek for the Countenance of their Lord Most High;
#  - [too_short] And soon will they attain (complete) satisfaction.
#  - [too_short] By the Glorious Morning Light,
#  - [too_short] Therefore, treat not the orphan with harshness,
#  - [too_short] Nor repulse the petitioner (unheard);
#  - [too_short] Have We not expanded thee thy breast?-
#  - [too_short] And removed from thee thy burden
#  - [too_short] The which did gall thy back?-
#  - [too_short] Verily, with every difficulty there is relief.
#  - [too_short] By the Fig and the Olive,
#  - [too_short] And the Mount of Sinai,
#  - [too_short] And this City of security,-
#  - [too_short] Is not Allah the wisest of judges?
#  - [high_capital_no_keywords] Proclaim! (or read!) in the name of thy Lord and Cherisher, Who created-
#  - [too_short] Proclaim! And thy Lord is Most Bountiful,-
#  - [too_short] Taught man that which he knew not.
#  - [too_short] Nay, but man doth transgress all bounds,
#  - [too_short] Seest thou one who forbids-
#  - [too_short] A votary when he (turns) to pray?
#  - [too_short] Or enjoins Righteousness?
#  - [too_short] Knoweth he not that Allah doth see?
#  - [too_short] A lying, sinful forelock!
#  - [high_capital_no_keywords] We have indeed revealed this (Message) in the Night of Power:
#  - [too_short] Peace!... This until the rise of morn!
#  - [too_short] And strike sparks of fire,
#  - [too_short] Truly man is, to his Lord, ungrateful;
#  - [too_short] The (Day) of Noise and Clamour:
#  - [high_capital_no_keywords] What is the (Day) of Noise and Clamour?
#  - [too_short] (It is) a Fire Blazing fiercely!
#  - [too_short] Until ye visit the graves.
#  - [too_short] Again, ye soon shall know!
#  - [too_short] Ye shall certainly see Hell-Fire!
#  - [high_capital_no_keywords] By (the Token of) Time (through the ages),
#  - [too_short] Verily Man is in loss,
#  - [too_short] Woe to every (kind of) scandal-monger and-backbiter,
#  - [high_capital_no_keywords] By no means! He will be sure to be thrown into That which Breaks to Pieces,
#  - [high_capital_no_keywords] And what will explain to thee That which Breaks to Pieces?
#  - [high_capital_no_keywords] (It is) the Fire of (the Wrath of) Allah kindled (to a blaze),
#  - [too_short] In columns outstretched.
#  - [high_capital_no_keywords] And He sent against them Flights of Birds,
#  - [too_short] Striking them with stones of baked clay.
#  - [too_short] So woe to the worshippers
#  - [too_short] Who are neglectful of their prayers,
#  - [too_short] But refuse (to supply) (even) neighbourly needs.
#  - [high_capital_no_keywords] To thee have We granted the Fount (of Abundance).
#  - [too_short] Say: O ye that reject Faith!
#  - [too_short] I worship not that which ye worship,
#  - [high_capital_no_keywords] When comes the Help of Allah, and Victory,
#  - [high_capital_no_keywords] Celebrate the praises of thy Lord, and pray for His Forgiveness: For He is Oft-Returning (in Grace and Mercy).
#  - [high_capital_no_keywords] Perish the hands of the Father of Flame! Perish he!
#  - [high_capital_no_keywords] Burnt soon will he be in a Fire of Blazing Flame!
#  - [high_capital_no_keywords] Say: He is Allah, the One and Only;
#  - [too_short] Allah, the Eternal, Absolute;
#  - [too_short] He begetteth not, nor is He begotten;
#  - [too_short] And there is none like unto Him.
#  - [too_short] From the mischief of created things;
#  - [high_capital_no_keywords] Say: I seek refuge with the Lord and Cherisher of Mankind,
#  - [too_short] The King (or Ruler) of Mankind,
#  - [too_short] The god (or judge) of Mankind,-
#  - [too_short] Among Jinns and among men.
# After advanced filtering: 149940 rows
# Combined dataset created with 149940 sentences
# Schools included: ['hinduism' 'confucianism' 'occult_esoteric' 'indigenous' 'christianity'
#  'sikhism' 'judaism' 'taoism' 'bahai' 'buddhism' 'zoroastrianism' 'islam']
# Sources included: 2 different sources
# Breakdown by school:
# school
# christianity       51317
# buddhism           45566
# occult_esoteric    20879
# sikhism             6589
# confucianism        6438
# hinduism            6263
# islam               5517
# bahai               3344
# taoism              1821
# zoroastrianism      1429
# indigenous           467
# judaism              310
# Name: count, dtype: int64

# %% [markdown]
# And that's it! When it came to modeling the data, we first worked on some basic [Bayesian models](https://github.com/kcalizadeh/phil_nlp/blob/master/Notebooks/2_non-neural_models.ipynb), before then moving on to [w2v](https://github.com/kcalizadeh/phil_nlp/blob/master/Notebooks/3_w2v.ipynb) and [neural networks](https://github.com/kcalizadeh/phil_nlp/blob/master/Notebooks/4_neural_networks.ipynb).

# %% [markdown]
# # Comprehensive Religious Text Cleaning
#
# This section contains cleaning functions for all religious texts according to specific requirements.

# %% [markdown]
# ## Test the Cleaning Functions
#
# Run the cell below to clean all religious texts in your revised_religion folder:
